# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

#1678 O-C

# %%
#install pyDF2
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /home/gerson/anaconda3/lib/python3.6/site-packages

# %%
# importing all the required modules
import PyPDF2

# %%
# creating an object 
file = open('notas.pdf', 'rb')

# %%
# creating a pdf reader object
fileReader = PyPDF2.PdfFileReader(file)

# %%
# print the number of pages in pdf file
print(fileReader)
# Out:
# <PyPDF2.pdf.PdfFileReader object at 0x7f9d89821278>

# %%
nro_paginas = fileReader.getNumPages()

# %%
TOTAL = []
count = 1
for page in range(nro_paginas):
    pagina = fileReader.getPage(page)
    texto_pagina=pagina.extractText()

    # Obteniendo el cuerpo
    # separando la cabecera
    body = texto_pagina.split("viernes 16 de  febrero 2018",1)
    body = body[1]
    body = body.split("OCAD-UNI")
    final_body = body[0]
    #final_body

    d = r'([A-Z][0-9]|[A-Z])-([0-9][0-9][0-9]|[A-Z]|[0-9][0-9][A-Z])'
    l = re.compile(d).split(final_body)
    #print(l)
        
    arrayAlumnos = []
    for i in range(0,len(l),3):
        raw_alumno = l[i]
        #print(raw_alumno)
        #print(raw_alumno)
        f = r'([0-9])|AUSENTE'
        test = re.compile(f).split(raw_alumno,1)
        name = test[0]
        resto = test[1:]
        print(resto)
        resto = ['AUSENTE' if v is None else v for v in resto]
        raw_notas  = ''.join(resto)
        gg = r',([0-9]{3})|AUSENTE'
        test2 = re.compile(gg).split(raw_notas)
        test2 = ['0' if v is None else v for v in test2]
        test2 = ['0' if v is '' else v for v in test2]
        print(test2)
        if(len(test2)==1):
            break
        notas = []
        for i in range(0,len(test2)-1,2):
            #print(test2)
            dec = test2[i]
            cent = test2[i+1]
            tota_num = dec + '.' + cent
            final_num = float(tota_num)
            notas.append(final_num)
        
        # Aca obtenemos el codigo del alumno
        codigo = test2[len(test2)-1]
        print(codigo)
        print(count)
        firstNUM = str(count)
        print(firstNUM)
        codigo = codigo.replace(firstNUM, "", 1)
        codigo = codigo.replace("*", "")
        codigo = codigo.replace(" ", "")

        count=count+1
       
        # print(notas)
        alumno = {}
        if len(notas) !=0:
            alumno['codigo'] = codigo
            alumno['nombre'] = name
            alumno['examen1'] = notas[0]
            alumno['examen2'] = notas[1]
            alumno['total'] = notas[2]            
            arrayAlumnos.append(alumno)
    
    TOTAL = TOTAL + arrayAlumnos
# Out:
# ['4', '46,08075,000 521,080 151897DG2-252ABANTO OCMIN MARTIN GUILLERMO210,5201,000 211,520 230346D*A2-239ABARCA TINEO EDGAR JUNIOR559,720240,000 799,720 341901FI7-202ABARCA VILLANUEVA PILAR MAURA183,480174,000 357,480 441032GA2-239ABATE DOMINGUEZ JOEL SMITH342,120180,000 522,120 562514FG2-332ABERGA BELLIDO GIAN PIERO265,08027,000 292,080 642154HQ1-207ABREGO CRUZ LUIS MIGUEL297,400363,000 660,400 741919FA2-239ABREGO HILARIO SAMANTA LEA312,60084,000 396,600 850048GC1-228ABREGO YUCRA JENNIFER MARITZA505,840312,000 817,840 940263FG2-252ABREGU CHILQUILLO AILTON ALEX429,680351,000 780,680 1081001KG2-252ABURTO RAMÍREZ ALEXANDER MANUEL506,520399,000 905,520 1141613KC1-228ACASIETE ARIAS ERNESTO ANIBAL432,24012,000 444,240 1242077FD2-321ACERO CARRION JULIO MIGUEL522,120249,000 771,120 1340022AH4-225ACERO RODRIGUEZ SHIRLEY MERCY578,600267,000 845,600 1410484KG2-272ACEVEDO AGUERO GIAN POOL460,960282,000 742,960 1581002KR1-411ACEVEDO CALLE GUILLERMO411,52018,000 429,520 1641291JD2-361ACEVEDO GAGO LIZ PATRICH ANKY395,360135,000 530,360 1732348GI7-103ACHA CONDORI ERIKA VALERIA506,840291,000 797,840 1858006FG2-252ACHALMA GALINDO MARIO FERNANDO426,320450,000 876,320 1920751EQ1-201ACHAYA SURCO HENRY LUIS359,200297,000 656,200 2020642CA2-252ACHONG BONILLA JORGE GUILLERMO453,720276,000 729,720 2162901JH4-145ACORI VALLES JORGE LUIS285,32060,000 345,320 2230085FQ1-201ACOSTA CASIQUE LUIS FERNANDO JUNIOR481,480180,000 661,480 2362833GQ1-206ACOSTA CHAPOÑAN MARIA BENEDICTA526,400384,000 910,400 2430263EA2-239ACOSTA CORREA ANGEL BRYAN488,480276,000 764,480 2531787FIO-301ACOSTA GIRALDEZ ARON JUNIOR282,920312,000 594,920 2660391BC1-228ACOSTA JULCA DONNA MARIA MERCEDES479,640165,000 644,640 2710089BQ1-201ACOSTA MEZA CRISTHIAN FAUSTO423,440324,000 747,440 2820388GQ1-201ACOSTA SULCA ALEX CRISTIAN389,400357,000 746,400 2930258DQ1-201ACOSTA TINGAL JOHAN LEONARDO410,760141,000 551,760 3032391CH4-145ACUÑA ASENJO JAVIER ALEXANDER462,520345,000 807,520 3130398AIO-301ACUÑA CALDERÓN RYS DAYBID289,600357,000 646,600 3220436BQ1-206ACUÑA ENRIQUEZ JHON387,720390,000 777,720 3340179DD2-361ACUÑA HUERTA YORDI BRAYAN466,120318,000 784,120 3462351AA2-239ACUÑA LLANOS TINO ALEJANDRO437,280144,000 581,280 3562992GQ1-206ACUÑA MEJIA JORGE LUIS366,640366,000 732,640 3631638JH4-225ACUÑA PIMENTEL RAMIRO275,520150,000 425,520 3741795AQ1-206ACUÑA PROLEON JHOJAN ALEJANDRO339,960390,000 729,960 3840896GIO-301ACUÑA SIERRA ISAAC DEREK400,360303,000 703,360 3962886IH4-225ACUÑA VALENCIA YENDI DAYANE452,120369,000 821,120 4060251ED2-361ADAMA FLORES ANTHONY CRISTHOPER454,640180,000 634,640 4120573FG2-302ADUVIRI SONCO MARGA PRINCESA234,08078,000 312,080 4230215FA2-242AGAMA SANTANA HANS WILLIAM360,240204,000 564,240 4362572IA2-242AGAMA SATURNO JOSEP KASELLY472,560366,000 838,560 4431972EQ1-201AGAPITO CUETO ANGEL DAVID378,760201,000 579,760 4530251BG2-262AGAPITO RODRIGUEZ JESUS ALBERTO435,760129,000 564,760 4662771JA2-269AGESTO FLORES QUEVIN236,7206,000 242,720 4720011AIO-301AGREDA FUNG LEONARDO ANDRÉ322,44045,000 367,440 4832313CG2-332AGUADO GUTIERREZ GERSON ALBERTO516,520312,000 828,520 4920061JH4-225AGUADO MONTALVAN AILTON DENYS421,920504,000 925,920 5020491AQ1-206AGUADO PAYANO GUILLERMO JOEL334,720246,000 580,720 5162690JI7-101AGUERO ARANGO ROGGERS CHRISTOPHER345,520258,000 603,520 5220230JH4-225AGUI ALVARADO JHOJAN KENNEDY249,08045,000 294,080 5341785HC1-228AGUILAR ACOSTA JESUS ORLANDO254,440108,000 362,440 5462472FG2-262AGUILAR ALDANA MARTÍN ANGEL485,400426,000 911,400 5520520DA2-242']
# ['446', '080', '75', '000', ' 521', '080', ' 151897DG2-252ABANTO OCMIN MARTIN GUILLERMO210', '520', '1', '000', ' 211', '520', ' 230346D*A2-239ABARCA TINEO EDGAR JUNIOR559', '720', '240', '000', ' 799', '720', ' 341901FI7-202ABARCA VILLANUEVA PILAR MAURA183', '480', '174', '000', ' 357', '480', ' 441032GA2-239ABATE DOMINGUEZ JOEL SMITH342', '120', '180', '000', ' 522', '120', ' 562514FG2-332ABERGA BELLIDO GIAN PIERO265', '080', '27', '000', ' 292', '080', ' 642154HQ1-207ABREGO CRUZ LUIS MIGUEL297', '400', '363', '000', ' 660', '400', ' 741919FA2-239ABREGO HILARIO SAMANTA LEA312', '600', '84', '000', ' 396', '600', ' 850048GC1-228ABREGO YUCRA JENNIFER MARITZA505', '840', '312', '000', ' 817', '840', ' 940263FG2-252ABREGU CHILQUILLO AILTON ALEX429', '680', '351', '000', ' 780', '680', ' 1081001KG2-252ABURTO RAMÍREZ ALEXANDER MANUEL506', '520', '399', '000', ' 905', '520', ' 1141613KC1-228ACASIETE ARIAS ERNESTO ANIBAL432', '240', '12', '000', ' 444', '240', ' 1242077FD2-321ACERO CARRION JULIO MIGUEL522', '120', '249', '000', ' 771', '120', ' 1340022AH4-225ACERO RODRIGUEZ SHIRLEY MERCY578', '600', '267', '000', ' 845', '600', ' 1410484KG2-272ACEVEDO AGUERO GIAN POOL460', '960', '282', '000', ' 742', '960', ' 1581002KR1-411ACEVEDO CALLE GUILLERMO411', '520', '18', '000', ' 429', '520', ' 1641291JD2-361ACEVEDO GAGO LIZ PATRICH ANKY395', '360', '135', '000', ' 530', '360', ' 1732348GI7-103ACHA CONDORI ERIKA VALERIA506', '840', '291', '000', ' 797', '840', ' 1858006FG2-252ACHALMA GALINDO MARIO FERNANDO426', '320', '450', '000', ' 876', '320', ' 1920751EQ1-201ACHAYA SURCO HENRY LUIS359', '200', '297', '000', ' 656', '200', ' 2020642CA2-252ACHONG BONILLA JORGE GUILLERMO453', '720', '276', '000', ' 729', '720', ' 2162901JH4-145ACORI VALLES JORGE LUIS285', '320', '60', '000', ' 345', '320', ' 2230085FQ1-201ACOSTA CASIQUE LUIS FERNANDO JUNIOR481', '480', '180', '000', ' 661', '480', ' 2362833GQ1-206ACOSTA CHAPOÑAN MARIA BENEDICTA526', '400', '384', '000', ' 910', '400', ' 2430263EA2-239ACOSTA CORREA ANGEL BRYAN488', '480', '276', '000', ' 764', '480', ' 2531787FIO-301ACOSTA GIRALDEZ ARON JUNIOR282', '920', '312', '000', ' 594', '920', ' 2660391BC1-228ACOSTA JULCA DONNA MARIA MERCEDES479', '640', '165', '000', ' 644', '640', ' 2710089BQ1-201ACOSTA MEZA CRISTHIAN FAUSTO423', '440', '324', '000', ' 747', '440', ' 2820388GQ1-201ACOSTA SULCA ALEX CRISTIAN389', '400', '357', '000', ' 746', '400', ' 2930258DQ1-201ACOSTA TINGAL JOHAN LEONARDO410', '760', '141', '000', ' 551', '760', ' 3032391CH4-145ACUÑA ASENJO JAVIER ALEXANDER462', '520', '345', '000', ' 807', '520', ' 3130398AIO-301ACUÑA CALDERÓN RYS DAYBID289', '600', '357', '000', ' 646', '600', ' 3220436BQ1-206ACUÑA ENRIQUEZ JHON387', '720', '390', '000', ' 777', '720', ' 3340179DD2-361ACUÑA HUERTA YORDI BRAYAN466', '120', '318', '000', ' 784', '120', ' 3462351AA2-239ACUÑA LLANOS TINO ALEJANDRO437', '280', '144', '000', ' 581', '280', ' 3562992GQ1-206ACUÑA MEJIA JORGE LUIS366', '640', '366', '000', ' 732', '640', ' 3631638JH4-225ACUÑA PIMENTEL RAMIRO275', '520', '150', '000', ' 425', '520', ' 3741795AQ1-206ACUÑA PROLEON JHOJAN ALEJANDRO339', '960', '390', '000', ' 729', '960', ' 3840896GIO-301ACUÑA SIERRA ISAAC DEREK400', '360', '303', '000', ' 703', '360', ' 3962886IH4-225ACUÑA VALENCIA YENDI DAYANE452', '120', '369', '000', ' 821', '120', ' 4060251ED2-361ADAMA FLORES ANTHONY CRISTHOPER454', '640', '180', '000', ' 634', '640', ' 4120573FG2-302ADUVIRI SONCO MARGA PRINCESA234', '080', '78', '000', ' 312', '080', ' 4230215FA2-242AGAMA SANTANA HANS WILLIAM360', '240', '204', '000', ' 564', '240', ' 4362572IA2-242AGAMA SATURNO JOSEP KASELLY472', '560', '366', '000', ' 838', '560', ' 4431972EQ1-201AGAPITO CUETO ANGEL DAVID378', '760', '201', '000', ' 579', '760', ' 4530251BG2-262AGAPITO RODRIGUEZ JESUS ALBERTO435', '760', '129', '000', ' 564', '760', ' 4662771JA2-269AGESTO FLORES QUEVIN236', '720', '6', '000', ' 242', '720', ' 4720011AIO-301AGREDA FUNG LEONARDO ANDRÉ322', '440', '45', '000', ' 367 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-2eff941e7dcc> in <module>()
#      42             cent = test2[i+1]
#      43             tota_num = dec + '.' + cent
# ---> 44             final_num = float(tota_num)
#      45             notas.append(final_num)
#      46
#
# ValueError: could not convert string to float: ' 151897DG2-252ABANTO OCMIN MARTIN GUILLERMO210.520'

# %%
TOTAL
# Out:
# [{'codigo': '51897D',
#   'examen1': 446.08,
#   'examen2': 75.0,
#   'nombre': 'ABANTO ARRIOLA STEPHANIE GIOVANA',
#   'total': 521.08},
#  {'codigo': '230346D',
#   'examen1': 210.52,
#   'examen2': 1.0,
#   'nombre': 'ABANTO OCMIN MARTIN GUILLERMO',
#   'total': 211.52},
#  {'codigo': '34901F',
#   'examen1': 559.72,
#   'examen2': 240.0,
#   'nombre': 'ABARCA TINEO EDGAR JUNIOR',
#   'total': 799.72},
#  {'codigo': '44032G',
#   'examen1': 183.48,
#   'examen2': 174.0,
#   'nombre': 'ABARCA VILLANUEVA PILAR MAURA',
#   'total': 357.48},
#  {'codigo': '56254F',
#   'examen1': 342.12,
#   'examen2': 180.0,
#   'nombre': 'ABATE DOMINGUEZ JOEL SMITH',
#   'total': 522.12},
#  {'codigo': '64254H',
#   'examen1': 265.08,
#   'examen2': 27.0,
#   'nombre': 'ABERGA BELLIDO GIAN PIERO',
#   'total': 292.08},
#  {'codigo': '74919F',
#   'examen1': 297.4,
#   'examen2': 363.0,
#   'nombre': 'ABREGO CRUZ LUIS MIGUEL',
#   'total': 660.4},
#  {'codigo': '850048G',
#   'examen1': 312.6,
#   'examen2': 84.0,
#   'nombre': 'ABREGO HILARIO SAMANTA LEA',
#   'total': 396.6},
#  {'codigo': '940263F',
#   'examen1': 505.84,
#   'examen2': 312.0,
#   'nombre': 'ABREGO YUCRA JENNIFER MARITZA',
#   'total': 817.84},
#  {'codigo': '081001K',
#   'examen1': 429.68,
#   'examen2': 351.0,
#   'nombre': 'ABREGU CHILQUILLO AILTON ALEX',
#   'total': 780.68},
#  {'codigo': '141613K',
#   'examen1': 506.52,
#   'examen2': 399.0,
#   'nombre': 'ABURTO RAMÍREZ ALEXANDER MANUEL',
#   'total': 905.52},
#  {'codigo': '242077F',
#   'examen1': 432.24,
#   'examen2': 12.0,
#   'nombre': 'ACASIETE ARIAS ERNESTO ANIBAL',
#   'total': 444.24},
#  {'codigo': '340022A',
#   'examen1': 522.12,
#   'examen2': 249.0,
#   'nombre': 'ACERO CARRION JULIO MIGUEL',
#   'total': 771.12},
#  {'codigo': '410484K',
#   'examen1': 578.6,
#   'examen2': 267.0,
#   'nombre': 'ACERO RODRIGUEZ SHIRLEY MERCY',
#   'total': 845.6},
#  {'codigo': '581002K',
#   'examen1': 460.96,
#   'examen2': 282.0,
#   'nombre': 'ACEVEDO AGUERO GIAN POOL',
#   'total': 742.96},
#  {'codigo': '641291J',
#   'examen1': 411.52,
#   'examen2': 18.0,
#   'nombre': 'ACEVEDO CALLE GUILLERMO',
#   'total': 429.52},
#  {'codigo': '732348G',
#   'examen1': 395.36,
#   'examen2': 135.0,
#   'nombre': 'ACEVEDO GAGO LIZ PATRICH ANKY',
#   'total': 530.36},
#  {'codigo': '858006F',
#   'examen1': 506.84,
#   'examen2': 291.0,
#   'nombre': 'ACHA CONDORI ERIKA VALERIA',
#   'total': 797.84},
#  {'codigo': '920751E',
#   'examen1': 426.32,
#   'examen2': 450.0,
#   'nombre': 'ACHALMA GALINDO MARIO FERNANDO',
#   'total': 876.32},
#  {'codigo': '2020642C',
#   'examen1': 359.2,
#   'examen2': 297.0,
#   'nombre': 'ACHAYA SURCO HENRY LUIS',
#   'total': 656.2},
#  {'codigo': '262901J',
#   'examen1': 453.72,
#   'examen2': 276.0,
#   'nombre': 'ACHONG BONILLA JORGE GUILLERMO',
#   'total': 729.72},
#  {'codigo': '2230085F',
#   'examen1': 285.32,
#   'examen2': 60.0,
#   'nombre': 'ACORI VALLES JORGE LUIS',
#   'total': 345.32},
#  {'codigo': '2362833G',
#   'examen1': 481.48,
#   'examen2': 180.0,
#   'nombre': 'ACOSTA CASIQUE LUIS FERNANDO JUNIOR',
#   'total': 661.48},
#  {'codigo': '2430263E',
#   'examen1': 526.4,
#   'examen2': 384.0,
#   'nombre': 'ACOSTA CHAPOÑAN MARIA BENEDICTA',
#   'total': 910.4},
#  {'codigo': '253787FI',
#   'examen1': 488.48,
#   'examen2': 276.0,
#   'nombre': 'ACOSTA CORREA ANGEL BRYAN',
#   'total': 764.48},
#  {'codigo': '266039B',
#   'examen1': 282.92,
#   'examen2': 312.0,
#   'nombre': 'ACOSTA GIRALDEZ ARON JUNIOR',
#   'total': 594.92},
#  {'codigo': '270089B',
#   'examen1': 479.64,
#   'examen2': 165.0,
#   'nombre': 'ACOSTA JULCA DONNA MARIA MERCEDES',
#   'total': 644.64},
#  {'codigo': '2820388G',
#   'examen1': 423.44,
#   'examen2': 324.0,
#   'nombre': 'ACOSTA MEZA CRISTHIAN FAUSTO',
#   'total': 747.44},
#  {'codigo': '2930258D',
#   'examen1': 389.4,
#   'examen2': 357.0,
#   'nombre': 'ACOSTA SULCA ALEX CRISTIAN',
#   'total': 746.4},
#  {'codigo': '303239C',
#   'examen1': 410.76,
#   'examen2': 141.0,
#   'nombre': 'ACOSTA TINGAL JOHAN LEONARDO',
#   'total': 551.76},
#  {'codigo': '330398AI',
#   'examen1': 462.52,
#   'examen2': 345.0,
#   'nombre': 'ACUÑA ASENJO JAVIER ALEXANDER',
#   'total': 807.52},
#  {'codigo': '3220436B',
#   'examen1': 289.6,
#   'examen2': 357.0,
#   'nombre': 'ACUÑA CALDERÓN RYS DAYBID',
#   'total': 646.6},
#  {'codigo': '334079D',
#   'examen1': 387.72,
#   'examen2': 390.0,
#   'nombre': 'ACUÑA ENRIQUEZ JHON',
#   'total': 777.72},
#  {'codigo': '346235A',
#   'examen1': 466.12,
#   'examen2': 318.0,
#   'nombre': 'ACUÑA HUERTA YORDI BRAYAN',
#   'total': 784.12},
#  {'codigo': '3562992G',
#   'examen1': 437.28,
#   'examen2': 144.0,
#   'nombre': 'ACUÑA LLANOS TINO ALEJANDRO',
#   'total': 581.28},
#  {'codigo': '363638J',
#   'examen1': 366.64,
#   'examen2': 366.0,
#   'nombre': 'ACUÑA MEJIA JORGE LUIS',
#   'total': 732.64},
#  {'codigo': '374795A',
#   'examen1': 275.52,
#   'examen2': 150.0,
#   'nombre': 'ACUÑA PIMENTEL RAMIRO',
#   'total': 425.52},
#  {'codigo': '3840896GI',
#   'examen1': 339.96,
#   'examen2': 390.0,
#   'nombre': 'ACUÑA PROLEON JHOJAN ALEJANDRO',
#   'total': 729.96},
#  {'codigo': '3962886I',
#   'examen1': 400.36,
#   'examen2': 303.0,
#   'nombre': 'ACUÑA SIERRA ISAAC DEREK',
#   'total': 703.36},
#  {'codigo': '406025E',
#   'examen1': 452.12,
#   'examen2': 369.0,
#   'nombre': 'ACUÑA VALENCIA YENDI DAYANE',
#   'total': 821.12},
#  {'codigo': '420573F',
#   'examen1': 454.64,
#   'examen2': 180.0,
#   'nombre': 'ADAMA FLORES ANTHONY CRISTHOPER',
#   'total': 634.64},
#  {'codigo': '423025F',
#   'examen1': 234.08,
#   'examen2': 78.0,
#   'nombre': 'ADUVIRI SONCO MARGA PRINCESA',
#   'total': 312.08},
#  {'codigo': '4362572I',
#   'examen1': 360.24,
#   'examen2': 204.0,
#   'nombre': 'AGAMA SANTANA HANS WILLIAM',
#   'total': 564.24},
#  {'codigo': '443972E',
#   'examen1': 472.56,
#   'examen2': 366.0,
#   'nombre': 'AGAMA SATURNO JOSEP KASELLY',
#   'total': 838.56},
#  {'codigo': '453025B',
#   'examen1': 378.76,
#   'examen2': 201.0,
#   'nombre': 'AGAPITO CUETO ANGEL DAVID',
#   'total': 579.76},
#  {'codigo': '466277J',
#   'examen1': 435.76,
#   'examen2': 129.0,
#   'nombre': 'AGAPITO RODRIGUEZ JESUS ALBERTO',
#   'total': 564.76},
#  {'codigo': '472001AI',
#   'examen1': 236.72,
#   'examen2': 6.0,
#   'nombre': 'AGESTO FLORES QUEVIN',
#   'total': 242.72},
#  {'codigo': '483233C',
#   'examen1': 322.44,
#   'examen2': 45.0,
#   'nombre': 'AGREDA FUNG LEONARDO ANDRÉ',
#   'total': 367.44},
#  {'codigo': '492006J',
#   'examen1': 516.52,
#   'examen2': 312.0,
#   'nombre': 'AGUADO GUTIERREZ GERSON ALBERTO',
#   'total': 828.52},
#  {'codigo': '502049A',
#   'examen1': 421.92,
#   'examen2': 504.0,
#   'nombre': 'AGUADO MONTALVAN AILTON DENYS',
#   'total': 925.92},
#  {'codigo': '562690J',
#   'examen1': 334.72,
#   'examen2': 246.0,
#   'nombre': 'AGUADO PAYANO GUILLERMO JOEL',
#   'total': 580.72},
#  {'codigo': '5220230J',
#   'examen1': 345.52,
#   'examen2': 258.0,
#   'nombre': 'AGUERO ARANGO ROGGERS CHRISTOPHER',
#   'total': 603.52},
#  {'codigo': '534785H',
#   'examen1': 249.08,
#   'examen2': 45.0,
#   'nombre': 'AGUI ALVARADO JHOJAN KENNEDY',
#   'total': 294.08},
#  {'codigo': '5462472F',
#   'examen1': 254.44,
#   'examen2': 108.0,
#   'nombre': 'AGUILAR ACOSTA JESUS ORLANDO',
#   'total': 362.44},
#  {'codigo': '5520520D',
#   'examen1': 485.4,
#   'examen2': 426.0,
#   'nombre': 'AGUILAR ALDANA MARTÍN ANGEL',
#   'total': 911.4},
#  {'codigo': '563084E',
#   'examen1': 325.72,
#   'examen2': 159.0,
#   'nombre': 'AGUILAR ANTICONA DARWIN OMAR',
#   'total': 484.72},
#  {'codigo': '576249A',
#   'examen1': 483.48,
#   'examen2': 516.0,
#   'nombre': 'AGUILAR AYMACHOQUE ALBERTO BENIGNO',
#   'total': 999.48},
#  {'codigo': '587001K',
#   'examen1': 0.0,
#   'examen2': 0.0,
#   'nombre': 'AGUILAR AYMACHOQUE ROSARIO VIRGINIA',
#   'total': 0.0},
#  {'codigo': '593414K',
#   'examen1': 428.36,
#   'examen2': 354.0,
#   'nombre': 'AGUILAR BURGOS FABRIZIO GIAN FRANCO',
#   'total': 782.36},
#  {'codigo': '606016K',
#   'examen1': 410.08,
#   'examen2': 426.0,
#   'nombre': 'AGUILAR CALLUPE BRAYAN LEONEL',
#   'total': 836.08},
#  {'codigo': '6140099I',
#   'examen1': 539.96,
#   'examen2': 489.0,
#   'nombre': 'AGUILAR CARHUAS JUAN RICARDO',
#   'total': 1028.96},
#  {'codigo': '610360B',
#   'examen1': 401.8,
#   'examen2': 267.0,
#   'nombre': 'AGUILAR CARRILLO DAVID FERNANDO',
#   'total': 668.8},
#  {'codigo': '636768H',
#   'examen1': 466.88,
#   'examen2': 213.0,
#   'nombre': 'AGUILAR CORDOVA RAFAEL JUNIOR',
#   'total': 679.88},
#  {'codigo': '646222B',
#   'examen1': 364.36,
#   'examen2': 300.0,
#   'nombre': 'AGUILAR COTRINA JHAMIRZOM OSCAR',
#   'total': 664.36},
#  {'codigo': '6531709F',
#   'examen1': 442.32,
#   'examen2': 300.0,
#   'nombre': 'AGUILAR DOMINGUEZ JERSSON ALDAIR',
#   'total': 742.32},
#  {'codigo': '6640933D',
#   'examen1': 512.68,
#   'examen2': 531.0,
#   'nombre': 'AGUILAR ESPINAL ALEXIS JOEL PEDRO',
#   'total': 1043.68},
#  {'codigo': '675166E',
#   'examen1': 351.32,
#   'examen2': 30.0,
#   'nombre': 'AGUILAR GALDOS ELVIRA DEL CARMEN',
#   'total': 381.32},
#  {'codigo': '686508K',
#   'examen1': 321.96,
#   'examen2': 303.0,
#   'nombre': 'AGUILAR HUAMAN EAR BRANDOLI',
#   'total': 624.96},
#  {'codigo': '690448E',
#   'examen1': 332.0,
#   'examen2': 261.0,
#   'nombre': 'AGUILAR JOÑAS JOSSEL STIP',
#   'total': 593.0},
#  {'codigo': '7040936H',
#   'examen1': 450.32,
#   'examen2': 393.0,
#   'nombre': 'AGUILAR MAGUIÑA MICHAEL WILLIAMS',
#   'total': 843.32},
#  {'codigo': '7140985A',
#   'examen1': 493.72,
#   'examen2': 270.0,
#   'nombre': 'AGUILAR MONTERO CLAUDIA ALONDRA',
#   'total': 763.72},
#  {'codigo': '730292A',
#   'examen1': 451.0,
#   'examen2': 270.0,
#   'nombre': 'AGUILAR ORTIZ DANNIEL RAYNALDO',
#   'total': 721.0},
#  {'codigo': '7331870C',
#   'examen1': 457.16,
#   'examen2': 438.0,
#   'nombre': "AGUILAR PALOMINO DAN O'NEILL ARIE",
#   'total': 895.16},
#  {'codigo': '7460313B',
#   'examen1': 483.56,
#   'examen2': 312.0,
#   'nombre': 'AGUILAR PAUCAR DANIEL ALEJANDRO',
#   'total': 795.56},
#  {'codigo': '756675E',
#   'examen1': 412.44,
#   'examen2': 531.0,
#   'nombre': 'AGUILAR PILLACA ANTHONY SEBASTIAN',
#   'total': 943.44},
#  {'codigo': '7641503D',
#   'examen1': 419.08,
#   'examen2': 222.0,
#   'nombre': 'AGUILAR QUIROZ SEBASTIAN ANDRE',
#   'total': 641.08},
#  {'codigo': '7730373A',
#   'examen1': 492.92,
#   'examen2': 423.0,
#   'nombre': 'AGUILAR RAFAEL ADRIAN',
#   'total': 915.92},
#  {'codigo': '784100B',
#   'examen1': 477.8,
#   'examen2': 216.0,
#   'nombre': 'AGUILAR RIVERA JOSUE CALEB',
#   'total': 693.8},
#  {'codigo': '796796J',
#   'examen1': 354.2,
#   'examen2': 342.0,
#   'nombre': 'AGUILAR SANCHEZ EDGAR ENRIQUE',
#   'total': 696.2},
#  {'codigo': '800267B',
#   'examen1': 389.76,
#   'examen2': 411.0,
#   'nombre': 'AGUILAR VASQUEZ DAVID',
#   'total': 800.76},
#  {'codigo': '816136A',
#   'examen1': 248.08,
#   'examen2': 186.0,
#   'nombre': 'AGUILAR VELEZ JAMES HOWARD PIERO',
#   'total': 434.08},
#  {'codigo': '831635F',
#   'examen1': 294.72,
#   'examen2': 96.0,
#   'nombre': 'AGUILAR ZEVALLOS JHOJAYRA SHIOMARA',
#   'total': 390.72},
#  {'codigo': '8341397J',
#   'examen1': 428.36,
#   'examen2': 168.0,
#   'nombre': 'AGUILERA RIVERA JAKSON STIWAR',
#   'total': 596.36},
#  {'codigo': '840172K',
#   'examen1': 288.0,
#   'examen2': 234.0,
#   'nombre': 'AGUIRRE ABREGU VANESSA SARAHI',
#   'total': 522.0},
#  {'codigo': '856079G',
#   'examen1': 424.08,
#   'examen2': 354.0,
#   'nombre': 'AGUIRRE ANGULO JESÚS SANTIAGO',
#   'total': 778.08},
#  {'codigo': '864218D',
#   'examen1': 395.8,
#   'examen2': 246.0,
#   'nombre': 'AGUIRRE BERROSPI JULINHO MARTÍN',
#   'total': 641.8},
#  {'codigo': '876421C',
#   'examen1': 388.4,
#   'examen2': 324.0,
#   'nombre': 'AGUIRRE CAMPOS KEN',
#   'total': 712.4},
#  {'codigo': '8831378F',
#   'examen1': 274.92,
#   'examen2': 81.0,
#   'nombre': 'AGUIRRE GAVILAN ALISON ABIGAIL',
#   'total': 355.92},
#  {'codigo': '893495D',
#   'examen1': 509.2,
#   'examen2': 249.0,
#   'nombre': 'AGUIRRE HUAMAN DAVID ROLANDO',
#   'total': 758.2},
#  {'codigo': '906302H',
#   'examen1': 471.4,
#   'examen2': 258.0,
#   'nombre': 'AGUIRRE PINTADO ELIAS EDUARDO',
#   'total': 729.4},
#  {'codigo': '9160406EI',
#   'examen1': 463.88,
#   'examen2': 384.0,
#   'nombre': 'AGUIRRE SANCHEZ KATHERIN PAOLA',
#   'total': 847.88},
#  {'codigo': '930022K',
#   'examen1': 302.32,
#   'examen2': 51.0,
#   'nombre': 'AGUIRRRE ZAVALA XIOMARA NICOLLE',
#   'total': 353.32},
#  {'codigo': '936125C',
#   'examen1': 388.0,
#   'examen2': 270.0,
#   'nombre': 'AGURTO CABANA JORGE ANTONIO',
#   'total': 658.0},
#  {'codigo': '946181G',
#   'examen1': 417.08,
#   'examen2': 240.0,
#   'nombre': 'AGURTO GOMEZ DINA ALLISON',
#   'total': 657.08},
#  {'codigo': '953538I',
#   'examen1': 303.64,
#   'examen2': 207.0,
#   'nombre': 'AGUSTIN ANGULO FRANK ALEXANDER',
#   'total': 510.64},
#  {'codigo': '9610346B',
#   'examen1': 355.76,
#   'examen2': 144.0,
#   'nombre': 'AGUSTIN SAMANIEGO LEONARDO',
#   'total': 499.76},
#  {'codigo': '973033D',
#   'examen1': 454.72,
#   'examen2': 285.0,
#   'nombre': 'AIRA FALCON ANTHONY JUAN JESUS',
#   'total': 739.72},
#  {'codigo': '9830157G',
#   'examen1': 561.0,
#   'examen2': 369.0,
#   'nombre': 'ALALUNA BÉJAR JOSÉ AYRTON',
#   'total': 930.0},
#  {'codigo': '996826G',
#   'examen1': 353.16,
#   'examen2': 189.0,
#   'nombre': 'ALANIA ARZAPALO GIANMARK RUFINO',
#   'total': 542.16},
#  {'codigo': '1004255E',
#   'examen1': 232.48,
#   'examen2': 78.0,
#   'nombre': 'ALANYA CHOMBO EMERSON ANTHONY',
#   'total': 310.48},
#  {'codigo': '1010708I',
#   'examen1': 458.84,
#   'examen2': 492.0,
#   'nombre': 'ALANYA VALENCIA DAVID ALEXANDER',
#   'total': 950.84},
#  {'codigo': '1010408J',
#   'examen1': 381.56,
#   'examen2': 228.0,
#   'nombre': 'ALARCÓN ALIAGA CHRISTOPHER DAVID',
#   'total': 609.56},
#  {'codigo': '1033078J',
#   'examen1': 407.4,
#   'examen2': 510.0,
#   'nombre': 'ALARCÓN CASTELLO RENATO ISRAEL',
#   'total': 917.4},
#  {'codigo': '1043617J',
#   'examen1': 246.24,
#   'examen2': 15.0,
#   'nombre': 'ALARCON DIAZ ALESSANDRO',
#   'total': 261.24},
#  {'codigo': '1050546II',
#   'examen1': 447.88,
#   'examen2': 201.0,
#   'nombre': 'ALARCÓN FERNÁNDEZ ANGELLI PAMELA',
#   'total': 648.88},
#  {'codigo': '10631850FI',
#   'examen1': 387.72,
#   'examen2': 171.0,
#   'nombre': 'ALARCON FERNANDEZ BRUNO SEBASTIAN',
#   'total': 558.72},
#  {'codigo': '10751781K',
#   'examen1': 264.52,
#   'examen2': 42.0,
#   'nombre': 'ALARCÓN FERNÁNDEZ NEYDER',
#   'total': 306.52},
#  {'codigo': '10858058C',
#   'examen1': 288.16,
#   'examen2': 42.0,
#   'nombre': 'ALARCÓN GUIZADO YAMILÉ ISABEL',
#   'total': 330.16},
#  {'codigo': '1093027G',
#   'examen1': 549.48,
#   'examen2': 423.0,
#   'nombre': 'ALARCON MARTEL ELMER RICARDO',
#   'total': 972.48},
#  {'codigo': '11010501KI',
#   'examen1': 363.52,
#   'examen2': 24.0,
#   'nombre': 'ALARCON MESIAS STEFANY AMELIA',
#   'total': 387.52},
#  {'codigo': '11162089K',
#   'examen1': 445.76,
#   'examen2': 297.0,
#   'nombre': 'ALARCON QUISPE DENNIS',
#   'total': 742.76},
#  {'codigo': '11262949K',
#   'examen1': 451.72,
#   'examen2': 264.0,
#   'nombre': 'ALARCON SALAZAR BRUNO JOAQUIN',
#   'total': 715.72},
#  {'codigo': '1163044E',
#   'examen1': 340.08,
#   'examen2': 297.0,
#   'nombre': 'ALARCON SUÁREZ RENZO SEBASTIÁN',
#   'total': 637.08},
#  {'codigo': '11420098BI',
#   'examen1': 455.76,
#   'examen2': 330.0,
#   'nombre': 'ALARCÓN TESÉN DANIEL ISAAC',
#   'total': 785.76},
#  {'codigo': '1154007H',
#   'examen1': 413.64,
#   'examen2': 258.0,
#   'nombre': 'ALARCÓN VÁSQUEZ ANTONIO',
#   'total': 671.64},
#  {'codigo': '11620046E',
#   'examen1': 456.72,
#   'examen2': 168.0,
#   'nombre': 'ALATA BAUTISTA SARAI ALEXANDRA',
#   'total': 624.72},
#  {'codigo': '1172367J',
#   'examen1': 492.48,
#   'examen2': 294.0,
#   'nombre': 'ALATA FERRIL FABRIZZIO ALESSANDRO',
#   'total': 786.48},
#  {'codigo': '1184166I',
#   'examen1': 451.04,
#   'examen2': 231.0,
#   'nombre': 'ALBA CULLASH HIPOLITO ROMARIO',
#   'total': 682.04},
#  {'codigo': '1199005A',
#   'examen1': 358.64,
#   'examen2': 198.0,
#   'nombre': 'ALBAN QUEVEDO NESTOR',
#   'total': 556.64},
#  {'codigo': '1208100K',
#   'examen1': 452.36,
#   'examen2': 315.0,
#   'nombre': 'ALBERCA DÍAZ GIANCARLO',
#   'total': 767.36},
#  {'codigo': '1211540D',
#   'examen1': 322.04,
#   'examen2': 39.0,
#   'nombre': 'ALBERCA SILVA CRISTHIAN BRAYAN',
#   'total': 361.04},
#  {'codigo': '12252005B',
#   'examen1': 257.72,
#   'examen2': 117.0,
#   'nombre': 'ALBERCO VILCAYAURI EDER YOSMAR',
#   'total': 374.72},
#  {'codigo': '1220016D',
#   'examen1': 253.76,
#   'examen2': 54.0,
#   'nombre': 'ALBERTO EBARISTO JHONY JOSE',
#   'total': 307.76},
#  {'codigo': '12462875K',
#   'examen1': 460.88,
#   'examen2': 243.0,
#   'nombre': 'ALBERTO GALINDO ROY KEVIN',
#   'total': 703.88},
#  {'codigo': '12541970G',
#   'examen1': 332.48,
#   'examen2': 15.0,
#   'nombre': 'ALBERTO QUISPE SHARON ESTRELLA',
#   'total': 347.48},
#  {'codigo': '12640041D',
#   'examen1': 394.68,
#   'examen2': 279.0,
#   'nombre': 'ALBINES FABIAN LUIS FERNANDO',
#   'total': 673.68},
#  {'codigo': '1272071H',
#   'examen1': 397.08,
#   'examen2': 339.0,
#   'nombre': 'ALBINO CHAVA DIEGO ANTONIO',
#   'total': 736.08},
#  {'codigo': '12841244E',
#   'examen1': 545.48,
#   'examen2': 399.0,
#   'nombre': 'ALBORNOZ GAGO RENZO WILLIAM',
#   'total': 944.48},
#  {'codigo': '1290399F',
#   'examen1': 467.0,
#   'examen2': 348.0,
#   'nombre': 'ALBORNOZ GARAY GENE CIRO',
#   'total': 815.0},
#  {'codigo': '1081004K',
#   'examen1': 397.16,
#   'examen2': 144.0,
#   'nombre': 'ALBORNOZ HERRERA ELIANA MILAGROS',
#   'total': 541.16},
#  {'codigo': '1141442A',
#   'examen1': 414.76,
#   'examen2': 264.0,
#   'nombre': 'ALBORNOZ LEIVA CESAR DENIS',
#   'total': 678.76},
#  {'codigo': '1262767C',
#   'examen1': 315.6,
#   'examen2': 291.0,
#   'nombre': 'ALBORNOZ PADILLA JOSUE NEHEMIAS',
#   'total': 606.6},
#  {'codigo': '1320462E',
#   'examen1': 462.36,
#   'examen2': 270.0,
#   'nombre': 'ALBORNOZ RIVERA MIGUEL STEPHANO',
#   'total': 732.36},
#  {'codigo': '1490021A',
#   'examen1': 342.8,
#   'examen2': 96.0,
#   'nombre': 'ALBORNOZ RIVERA RENZO HERNAN',
#   'total': 438.8},
#  {'codigo': '1531408CI',
#   'examen1': 397.04,
#   'examen2': 120.0,
#   'nombre': 'ALBURUQUEQUE LOA ANDRE IMANOL',
#   'total': 517.04},
#  {'codigo': '1658031I',
#   'examen1': 494.68,
#   'examen2': 330.0,
#   'nombre': 'ALCA HACHO PAOLA LELY',
#   'total': 824.68},
#  {'codigo': '1710185G',
#   'examen1': 335.28,
#   'examen2': 261.0,
#   'nombre': 'ALCA HUARCAYA LEYDY LUZ',
#   'total': 596.28},
#  {'codigo': '1830324H',
#   'examen1': 345.64,
#   'examen2': 150.0,
#   'nombre': 'ALCALÁ SANDOVAL ANTONY GIANDRE',
#   'total': 495.64},
#  {'codigo': '1932252K',
#   'examen1': 367.56,
#   'examen2': 132.0,
#   'nombre': 'ALCALDE SALDAÑA CHRISTIAN DAVID',
#   'total': 499.56},
#  {'codigo': '1402214E',
#   'examen1': 436.32,
#   'examen2': 252.0,
#   'nombre': 'ALCALDE VICENTE JULIO SERGIO',
#   'total': 688.32},
#  {'codigo': '1410078F',
#   'examen1': 536.68,
#   'examen2': 489.0,
#   'nombre': 'ALCANTARA ANTON CRISTIAN ALDAIR',
#   'total': 1025.68},
#  {'codigo': '1422002D',
#   'examen1': 457.76,
#   'examen2': 414.0,
#   'nombre': 'ALCANTARA ASTETE KENYI HERRY',
#   'total': 871.76},
#  {'codigo': '1431677J',
#   'examen1': 584.36,
#   'examen2': 582.0,
#   'nombre': 'ALCANTARA CASTILLO RAUL ALFREDO',
#   'total': 1166.36},
#  {'codigo': '14410249C',
#   'examen1': 330.76,
#   'examen2': 30.0,
#   'nombre': 'ALCANTARA CHAQUILA JOSÉ ALBERTO',
#   'total': 360.76},
#  {'codigo': '1452074K',
#   'examen1': 343.32,
#   'examen2': 36.0,
#   'nombre': 'ALCANTARA CHUCO ANTONIO',
#   'total': 379.32},
#  {'codigo': '1465180K',
#   'examen1': 506.24,
#   'examen2': 402.0,
#   'nombre': 'ALCANTARA CHUMPISUCA DANIEL IVO',
#   'total': 908.24},
#  {'codigo': '1472016I',
#   'examen1': 224.96,
#   'examen2': 129.0,
#   'nombre': 'ALCANTARA GARCIA JORGE ALEXANDER',
#   'total': 353.96},
#  {'codigo': '14851945J',
#   'examen1': 485.68,
#   'examen2': 237.0,
#   'nombre': 'ALCANTARA MURGA WENDY ALEJANDRA',
#   'total': 722.68},
#  {'codigo': '14951628H',
#   'examen1': 443.72,
#   'examen2': 243.0,
#   'nombre': 'ALCANTARA QUIROZ DANIELA ALICIA',
#   'total': 686.72},
#  {'codigo': '15051678FI',
#   'examen1': 408.16,
#   'examen2': 192.0,
#   'nombre': 'ALCÁNTARA QUISPE DELIA',
#   'total': 600.16},
#  {'codigo': '15162080J',
#   'examen1': 431.92,
#   'examen2': 411.0,
#   'nombre': 'ALCANTARA REMENTERIA WILLIAM NILTON',
#   'total': 842.92},
#  {'codigo': '1522121B',
#   'examen1': 459.16,
#   'examen2': 522.0,
#   'nombre': 'ALCANTARA SANTOS PATRICK DIEGO',
#   'total': 981.16},
#  {'codigo': '1562791G',
#   'examen1': 405.28,
#   'examen2': 510.0,
#   'nombre': 'ALCANTARA TACORA BRUNO ALEXIS',
#   'total': 915.28},
#  {'codigo': '1544153GI',
#   'examen1': 547.8,
#   'examen2': 285.0,
#   'nombre': 'ALCANTARA VALDERRAMA SNAIDER SMITH',
#   'total': 832.8},
#  {'codigo': '15540997DI',
#   'examen1': 459.6,
#   'examen2': 168.0,
#   'nombre': 'ALCARRAZ PRADO DIEGO JHONATAN',
#   'total': 627.6},
#  {'codigo': '1564220E',
#   'examen1': 348.92,
#   'examen2': 108.0,
#   'nombre': 'ALCASIHUINCHA CCAHUAY EVELYN MADELI',
#   'total': 456.92},
#  {'codigo': '1572416J',
#   'examen1': 220.64,
#   'examen2': 102.0,
#   'nombre': 'ALCOCER RIVERA CALEB JACOB FRANCISCO',
#   'total': 322.64},
#  {'codigo': '1582288I',
#   'examen1': 279.4,
#   'examen2': 60.0,
#   'nombre': 'ALDANA SARRIA EDUARDO ADRIAN',
#   'total': 339.4},
#  {'codigo': '15941000G',
#   'examen1': 423.0,
#   'examen2': 192.0,
#   'nombre': 'ALDAO VARGAS NAHUEL MARTIN',
#   'total': 615.0},
#  {'codigo': '16060408D',
#   'examen1': 482.16,
#   'examen2': 354.0,
#   'nombre': 'ALDERETE ARROYO ARACELY ADA',
#   'total': 836.16},
#  {'codigo': '1612052H',
#   'examen1': 550.44,
#   'examen2': 411.0,
#   'nombre': 'ALDERETE CUEVA DIEGO EDUARDO',
#   'total': 961.44},
#  {'codigo': '1622470D',
#   'examen1': 441.68,
#   'examen2': 441.0,
#   'nombre': 'ALDERETE VALENCIA DAVIS KEENYO',
#   'total': 882.68},
#  {'codigo': '1610405F',
#   'examen1': 417.56,
#   'examen2': 108.0,
#   'nombre': 'ALE CRUZ ANGELA',
#   'total': 525.56},
#  {'codigo': '1646025E',
#   'examen1': 292.36,
#   'examen2': 183.0,
#   'nombre': 'ALEGRE PORRAS WILLIAM BRYAN',
#   'total': 475.36},
#  {'codigo': '16562410E',
#   'examen1': 417.84,
#   'examen2': 303.0,
#   'nombre': 'ALEGRIA ESPINOZA LUIGUI ENRIQUE',
#   'total': 720.84},
#  {'codigo': '1661724A',
#   'examen1': 465.2,
#   'examen2': 408.0,
#   'nombre': 'ALEJANDRO JARA GUDBERTO ANGELO',
#   'total': 873.2},
#  {'codigo': '16731939BI',
#   'examen1': 462.28,
#   'examen2': 186.0,
#   'nombre': 'ALEJANDRO VASQUEZ CARLOS MOISES',
#   'total': 648.28},
#  {'codigo': '16862721A',
#   'examen1': 368.48,
#   'examen2': 450.0,
#   'nombre': 'ALEJANDRO ZARATE JAREK JHOEL',
#   'total': 818.48},
#  {'codigo': '1691664C',
#   'examen1': 349.72,
#   'examen2': 297.0,
#   'nombre': 'ALEJANDRO ZARATE JAREK JHUSSEF',
#   'total': 646.72},
#  {'codigo': '17050096F',
#   'examen1': 357.96,
#   'examen2': 228.0,
#   'nombre': 'ALEJO CARDENAS EVA BELEN',
#   'total': 585.96},
#  {'codigo': '1716210A',
#   'examen1': 378.76,
#   'examen2': 75.0,
#   'nombre': 'ALEMAN NAVARRO CIELHO YOLANDA',
#   'total': 453.76},
#  {'codigo': '17262035D',
#   'examen1': 409.88,
#   'examen2': 309.0,
#   'nombre': 'ALEMAN RAMIREZ HAROLD ALONSO',
#   'total': 718.88},
#  {'codigo': '17331393KI',
#   'examen1': 372.68,
#   'examen2': 216.0,
#   'nombre': 'ALFARO ARROYO MANUEL JESÚS',
#   'total': 588.68},
#  {'codigo': '1732428B',
#   'examen1': 184.92,
#   'examen2': 48.0,
#   'nombre': 'ALFARO BORDA CLAUDIA ANGELICA',
#   'total': 232.92},
#  {'codigo': '1751741E',
#   'examen1': 423.4,
#   'examen2': 426.0,
#   'nombre': 'ALFARO GARCIA ANDY MANUEL',
#   'total': 849.4},
#  {'codigo': '17620571G',
#   'examen1': 428.2,
#   'examen2': 393.0,
#   'nombre': 'ALFARO QUISPE RICARDO JEREMY DE JESÚS',
#   'total': 821.2},
#  {'codigo': '17732225C',
#   'examen1': 398.2,
#   'examen2': 273.0,
#   'nombre': 'ALFARO RAMIREZ JOHAN EDISON',
#   'total': 671.2},
#  {'codigo': '17881005K',
#   'examen1': 502.44,
#   'examen2': 489.0,
#   'nombre': 'ALFONTE LUPACA DENIS CRISTIAN',
#   'total': 991.44},
#  {'codigo': '17932332F',
#   'examen1': 376.04,
#   'examen2': 213.0,
#   'nombre': 'ALHUAY ESTRADA JOSE IMANOL',
#   'total': 589.04},
#  {'codigo': '18020285KI',
#   'examen1': 277.6,
#   'examen2': 186.0,
#   'nombre': 'ALIAGA ASTO ANTHONY HEBER',
#   'total': 463.6},
#  {'codigo': '18152331C',
#   'examen1': 325.4,
#   'examen2': 87.0,
#   'nombre': 'ALIAGA CARTOLIN KATHERINE VERONICA MICHELLE',
#   'total': 412.4},
#  {'codigo': '18220033H',
#   'examen1': 445.12,
#   'examen2': 354.0,
#   'nombre': 'ALIAGA MACUCACHI FRANCISCO HERNAN',
#   'total': 799.12},
#  {'codigo': '1830079A',
#   'examen1': 224.36,
#   'examen2': 117.0,
#   'nombre': 'ALIAGA MAXIMILIANO CESAR EDDISON',
#   'total': 341.36},
#  {'codigo': '1831899A',
#   'examen1': 479.08,
#   'examen2': 201.0,
#   'nombre': 'ALIAGA VASQUEZ CAROLINA',
#   'total': 680.08},
#  {'codigo': '18530235C',
#   'examen1': 501.68,
#   'examen2': 375.0,
#   'nombre': 'ALLCA MELGAREJO ALEXANDER JESUS',
#   'total': 876.68},
#  {'codigo': '1861056B',
#   'examen1': 444.8,
#   'examen2': 405.0,
#   'nombre': 'ALLCCA MORA DANIEL JOSUE',
#   'total': 849.8},
#  {'codigo': '18732296C',
#   'examen1': 413.08,
#   'examen2': 321.0,
#   'nombre': 'ALMANZA NICASIO DARIO HERMINIO',
#   'total': 734.08},
#  {'codigo': '18832182I',
#   'examen1': 308.48,
#   'examen2': 357.0,
#   'nombre': 'ALMEIDA CHACON LEONARDO NIELS',
#   'total': 665.48},
#  {'codigo': '18932202B',
#   'examen1': 468.36,
#   'examen2': 426.0,
#   'nombre': 'ALMERCO QUISPE MARCO ALFREDO',
#   'total': 894.36},
#  {'codigo': '1901529I',
#   'examen1': 368.72,
#   'examen2': 324.0,
#   'nombre': 'ALMERCO ROJAS MILAGROS CAROLINA',
#   'total': 692.72},
#  {'codigo': '19158039F',
#   'examen1': 237.56,
#   'examen2': 177.0,
#   'nombre': 'ALMEYDA FLORES ROBERTO CARLOS',
#   'total': 414.56},
#  {'codigo': '1920069H',
#   'examen1': 342.96,
#   'examen2': 120.0,
#   'nombre': 'ALMEYDA PEDRAZA GIANFRANCO',
#   'total': 462.96},
#  {'codigo': '19332505D',
#   'examen1': 318.48,
#   'examen2': 60.0,
#   'nombre': 'ALMEYDA TIPIÁN JOSÉ ARMANDO',
#   'total': 378.48},
#  {'codigo': '1941811G',
#   'examen1': 323.16,
#   'examen2': 78.0,
#   'nombre': 'ALMONACID QUISPE LUIS KENTA',
#   'total': 401.16},
#  {'codigo': '19532130AI',
#   'examen1': 274.88,
#   'examen2': 57.0,
#   'nombre': 'ALOCEN DE LA CRUZ SAUL JUNIOR',
#   'total': 331.88},
#  {'codigo': '19662369A',
#   'examen1': 310.6,
#   'examen2': 72.0,
#   'nombre': 'ALONZO TAMAYO JAFETH EDUARDO',
#   'total': 382.6},
#  {'codigo': '19760127I',
#   'examen1': 532.08,
#   'examen2': 426.0,
#   'nombre': 'ALTAMIRANO LAZO OLENKA RITA',
#   'total': 958.08},
#  {'codigo': '1986300G',
#   'examen1': 517.56,
#   'examen2': 330.0,
#   'nombre': 'ALTAMIRANO MOYA ANTONIO ARTURO',
#   'total': 847.56},
#  {'codigo': '19931761A',
#   'examen1': 602.0,
#   'examen2': 486.0,
#   'nombre': 'ALTAMIRANO PACHECO ANGIE CELESTE',
#   'total': 1088.0},
#  {'codigo': '20031830I',
#   'examen1': 470.92,
#   'examen2': 249.0,
#   'nombre': 'ALTAMIRANO PEÑA JUNIOR JEMISSON',
#   'total': 719.92},
#  {'codigo': '2010307EI',
#   'examen1': 479.44,
#   'examen2': 237.0,
#   'nombre': 'ALTAMIRANO QUISPE FRANKLIN DEYVIS',
#   'total': 716.44},
#  {'codigo': '20220306I',
#   'examen1': 499.64,
#   'examen2': 360.0,
#   'nombre': 'ALVA CAMA BRYAN ROY',
#   'total': 859.64},
#  {'codigo': '20320275G',
#   'examen1': 371.92,
#   'examen2': 237.0,
#   'nombre': 'ALVA CASTILLO JAIME JONATHAN',
#   'total': 608.92},
#  {'codigo': '2030037G',
#   'examen1': 598.4,
#   'examen2': 447.0,
#   'nombre': 'ALVA CUADROS JUAN LUIS ALFONSO',
#   'total': 1045.4},
#  {'codigo': '20532088C',
#   'examen1': 425.96,
#   'examen2': 198.0,
#   'nombre': 'ALVA FLORES JOSÉ IGNACIO',
#   'total': 623.96},
#  {'codigo': '20620778D',
#   'examen1': 348.0,
#   'examen2': 69.0,
#   'nombre': 'ALVA NAVAS JORGE ABEL',
#   'total': 417.0},
#  {'codigo': '2073138E',
#   'examen1': 340.04,
#   'examen2': 99.0,
#   'nombre': 'ALVARADO ALEGRE LUIS GUSTAVO',
#   'total': 439.04},
#  {'codigo': '20831961G',
#   'examen1': 484.92,
#   'examen2': 198.0,
#   'nombre': 'ALVARADO BURGA JUAN ALEJANDRO',
#   'total': 682.92},
#  {'codigo': '20920713J',
#   'examen1': 309.56,
#   'examen2': 45.0,
#   'nombre': 'ALVARADO CARO JHEMERSON LUIS',
#   'total': 354.56},
#  {'codigo': '21081006K',
#   'examen1': 474.52,
#   'examen2': 363.0,
#   'nombre': 'ALVARADO DIAZ ANTONELLA ELIANNE',
#   'total': 837.52},
#  {'codigo': '2113283A',
#   'examen1': 322.24,
#   'examen2': 231.0,
#   'nombre': 'ALVARADO MENDOZA PIERO ALESSANDRO',
#   'total': 553.24},
#  {'codigo': '21263075K',
#   'examen1': 253.88,
#   'examen2': 51.0,
#   'nombre': 'ALVARADO MORE CRISTHOFER BRAYAN',
#   'total': 304.88},
#  {'codigo': '21332539C',
#   'examen1': 465.8,
#   'examen2': 375.0,
#   'nombre': 'ALVARADO PAZ VALERIA SOLANGE',
#   'total': 840.8},
#  {'codigo': '2130165A',
#   'examen1': 406.48,
#   'examen2': 264.0,
#   'nombre': 'ALVARADO PILLACA HENRY ANDERSON',
#   'total': 670.48},
#  {'codigo': '2151997F',
#   'examen1': 258.96,
#   'examen2': 57.0,
#   'nombre': 'ALVARADO PURIZACA NALLELY TREASURE',
#   'total': 315.96},
#  {'codigo': '2163107I',
#   'examen1': 419.04,
#   'examen2': 216.0,
#   'nombre': 'ALVARADO RAMOS MIGUEL ANGEL',
#   'total': 635.04},
#  {'codigo': '2171341D',
#   'examen1': 331.72,
#   'examen2': 372.0,
#   'nombre': 'ALVARADO SANTILLAN CHRISTIAN PAOLO',
#   'total': 703.72},
#  {'codigo': '2181600C',
#   'examen1': 401.48,
#   'examen2': 420.0,
#   'nombre': 'ALVARADO SULLCA SIXTO MELANIO',
#   'total': 821.48},
#  {'codigo': '2192074B',
#   'examen1': 465.8,
#   'examen2': 288.0,
#   'nombre': 'ALVAREZ ATAULLUCO KEVIN RICARDO',
#   'total': 753.8},
#  {'codigo': '22020563B',
#   'examen1': 453.44,
#   'examen2': 324.0,
#   'nombre': 'ALVAREZ BENAUTE KEYVIN IRVIN',
#   'total': 777.44},
#  {'codigo': '22162413I',
#   'examen1': 464.24,
#   'examen2': 225.0,
#   'nombre': 'ALVAREZ BERMUDEZ JOSÉ MARTÍN',
#   'total': 689.24},
#  {'codigo': '22281007K',
#   'examen1': 381.0,
#   'examen2': 177.0,
#   'nombre': 'ALVAREZ CANCINO XAVIER MIGUEL',
#   'total': 558.0},
#  {'codigo': '22332040B',
#   'examen1': 471.68,
#   'examen2': 237.0,
#   'nombre': 'ALVAREZ CANO BENEDICT JIMENA',
#   'total': 708.68},
#  {'codigo': '2242045D',
#   'examen1': 284.28,
#   'examen2': 189.0,
#   'nombre': 'ALVAREZ CHAMBI BRANDON ABEL',
#   'total': 473.28},
#  {'codigo': '2241373D',
#   'examen1': 455.64,
#   'examen2': 390.0,
#   'nombre': 'ALVAREZ CHANCAN DAYANNA KAIREL',
#   'total': 845.64},
#  {'codigo': '2264148J',
#   'examen1': 531.08,
#   'examen2': 213.0,
#   'nombre': 'ALVAREZ CONDORI DIEGO',
#   'total': 744.08},
#  {'codigo': '2271862K',
#   'examen1': 383.92,
#   'examen2': 192.0,
#   'nombre': 'ALVAREZ CUSI LUZ GRECIA',
#   'total': 575.92},
#  {'codigo': '22831688H',
#   'examen1': 508.04,
#   'examen2': 321.0,
#   'nombre': 'ALVAREZ DOMINGUEZ JOSE MARIA',
#   'total': 829.04},
#  {'codigo': '2291676G',
#   'examen1': 478.36,
#   'examen2': 231.0,
#   'nombre': 'ALVAREZ DUEÑAS ABEL RAY',
#   'total': 709.36},
#  {'codigo': '2301039F',
#   'examen1': 420.92,
#   'examen2': 333.0,
#   'nombre': 'ALVAREZ ESPINOZA JHONNY EDGAR',
#   'total': 753.92},
#  {'codigo': '2312042A',
#   'examen1': 488.84,
#   'examen2': 453.0,
#   'nombre': 'ALVAREZ HORNA DAVID MIGUEL',
#   'total': 941.84},
#  {'codigo': '23220687K',
#   'examen1': 348.24,
#   'examen2': 111.0,
#   'nombre': 'ALVAREZ LOPEZ HERIKSON',
#   'total': 459.24},
#  {'codigo': '23363012E',
#   'examen1': 313.16,
#   'examen2': 267.0,
#   'nombre': 'ALVAREZ MORALES INTI LUIS',
#   'total': 580.16},
#  {'codigo': '23463010F',
#   'examen1': 348.96,
#   'examen2': 111.0,
#   'nombre': 'ALVAREZ MORALES LUIS GERARDO',
#   'total': 459.96},
#  {'codigo': '2320416E',
#   'examen1': 381.12,
#   'examen2': 243.0,
#   'nombre': 'ALVAREZ OBREGON CARLOS FRANCIS',
#   'total': 624.12},
#  {'codigo': '23662119H',
#   'examen1': 464.68,
#   'examen2': 36.0,
#   'nombre': 'ALVAREZ RIOS NATALIA PAOLA',
#   'total': 500.68},
#  {'codigo': '2374094GI',
#   'examen1': 424.36,
#   'examen2': 240.0,
#   'nombre': 'ALVAREZ ROJAS CARLOS DANIEL',
#   'total': 664.36},
#  {'codigo': '23841694D',
#   'examen1': 365.84,
#   'examen2': 174.0,
#   'nombre': 'ALVAREZ SAUCEDO ANAYELI ALEXANDRA',
#   'total': 539.84},
#  {'codigo': '23940006B',
#   'examen1': 241.04,
#   'examen2': 132.0,
#   'nombre': 'ALVAREZ SOTELO EDGAR SEBASTIAN',
#   'total': 373.04},
#  {'codigo': '24040082C',
#   'examen1': 501.76,
#   'examen2': 219.0,
#   'nombre': 'ALVAREZ TUCTO FREI ALEJANDRO',
#   'total': 720.76},
#  {'codigo': '24160007II',
#   'examen1': 467.28,
#   'examen2': 363.0,
#   'nombre': 'ALVAREZ URETA MIJAEL GUSTAVO',
#   'total': 830.28},
#  {'codigo': '2424197J',
#   'examen1': 348.64,
#   'examen2': 186.0,
#   'nombre': 'ALVAREZ VALDERRAMA JUAN RUBEN',
#   'total': 534.64},
#  {'codigo': '24341092I',
#   'examen1': 398.56,
#   'examen2': 258.0,
#   'nombre': 'ALVAREZ YNZA FRANK ANTHONY',
#   'total': 656.56},
#  {'codigo': '2443278C',
#   'examen1': 369.52,
#   'examen2': 48.0,
#   'nombre': 'ALVARO ARIAS DARLYN BRESCIA',
#   'total': 417.52},
#  {'codigo': '2430343K',
#   'examen1': 421.88,
#   'examen2': 189.0,
#   'nombre': 'ALVARO MARAVI JHOCELYN YASMIN',
#   'total': 610.88},
#  {'codigo': '2460081J',
#   'examen1': 348.84,
#   'examen2': 135.0,
#   'nombre': 'ALVARO ROSALES ENZO SEBASTIAN',
#   'total': 483.84},
#  {'codigo': '24762120K',
#   'examen1': 472.56,
#   'examen2': 351.0,
#   'nombre': 'ALVINO LÓPEZ JESÚS EDILBERTO',
#   'total': 823.56},
#  {'codigo': '24820633D',
#   'examen1': 293.12,
#   'examen2': 198.0,
#   'nombre': 'ALVINO VASQUEZ GIAN CARLOS',
#   'total': 491.12},
#  {'codigo': '2493244E',
#   'examen1': 368.24,
#   'examen2': 258.0,
#   'nombre': 'ALVITES CORDOVA STEVEN LARRY',
#   'total': 626.24},
#  {'codigo': '2060245J',
#   'examen1': 410.4,
#   'examen2': 351.0,
#   'nombre': 'AMADO URIBE CRISTHIAN',
#   'total': 761.4},
#  {'codigo': '2141636A',
#   'examen1': 350.28,
#   'examen2': 222.0,
#   'nombre': 'AMADOR SILVESTRE CRISTIAN RUBEN',
#   'total': 572.28},
#  {'codigo': '2240882E',
#   'examen1': 408.2,
#   'examen2': 6.0,
#   'nombre': 'AMAMBAL ZUBIETA ANGHELITA MISHELLE',
#   'total': 414.2},
#  {'codigo': '2362336G',
#   'examen1': 412.84,
#   'examen2': 348.0,
#   'nombre': 'AMANZO GUERRA DIEGO ALONSO',
#   'total': 760.84},
#  {'codigo': '2431956F',
#   'examen1': 343.76,
#   'examen2': 132.0,
#   'nombre': 'AMARO MIRANDA LEONEL FELIPE',
#   'total': 475.76},
#  {'codigo': '2542204B',
#   'examen1': 497.36,
#   'examen2': 363.0,
#   'nombre': 'AMARO SALINAS MARYEDITH NICOL',
#   'total': 860.36},
#  {'codigo': '2610219B',
#   'examen1': 414.2,
#   'examen2': 219.0,
#   'nombre': 'AMAYA GARCIA ANGIE GRACIELITA',
#   'total': 633.2},
#  {'codigo': '2740259J',
#   'examen1': 447.08,
#   'examen2': 501.0,
#   'nombre': 'AMAYA HUAMANI LUIS ENRIQUE',
#   'total': 948.08},
#  {'codigo': '2820010G',
#   'examen1': 512.28,
#   'examen2': 258.0,
#   'nombre': 'AMBROCIO MILLA KATHERINE CELINE',
#   'total': 770.28},
#  {'codigo': '2960180I',
#   'examen1': 501.92,
#   'examen2': 408.0,
#   'nombre': 'AMBROSIO CAMAYO ERICK JULIAN',
#   'total': 909.92},
#  {'codigo': '26032632D',
#   'examen1': 423.08,
#   'examen2': 54.0,
#   'nombre': 'AMESQUITA HUARDIA MARIA DEL CARMEN',
#   'total': 477.08},
#  {'codigo': '26162714A',
#   'examen1': 390.96,
#   'examen2': 111.0,
#   'nombre': 'AMPUERO ARCOS BENJAMIN NESTOR ISRAEL',
#   'total': 501.96},
#  {'codigo': '26210391H',
#   'examen1': 378.84,
#   'examen2': 177.0,
#   'nombre': 'AMPUERO VALLADARES JUAN MANUEL',
#   'total': 555.84},
#  {'codigo': '26331944C',
#   'examen1': 384.84,
#   'examen2': 447.0,
#   'nombre': 'ANAMPA TELLO CRISTOPHER EDWIN',
#   'total': 831.84},
#  {'codigo': '2643176J',
#   'examen1': 391.56,
#   'examen2': 405.0,
#   'nombre': 'ANAYA QUISPE MANUEL',
#   'total': 796.56},
#  {'codigo': '2641321G',
#   'examen1': 321.28,
#   'examen2': 111.0,
#   'nombre': 'ANCACHI MAMANI YONY SAUL',
#   'total': 432.28},
#  {'codigo': '26640892I',
#   'examen1': 399.56,
#   'examen2': 117.0,
#   'nombre': 'ANCAJIMA PRADO GIANFRANCO',
#   'total': 516.56},
#  {'codigo': '2674217A',
#   'examen1': 390.68,
#   'examen2': 324.0,
#   'nombre': 'ANCAJIMA ROSAS JOHAN ANTONI',
#   'total': 714.68},
#  {'codigo': '26862694H',
#   'examen1': 480.72,
#   'examen2': 363.0,
#   'nombre': 'ANCCARI MONTES FAVIA MARIA',
#   'total': 843.72},
#  {'codigo': '26981008K',
#   'examen1': 414.96,
#   'examen2': 372.0,
#   'nombre': 'ANCCASI BELLIDO EDWIN LEON',
#   'total': 786.96},
#  {'codigo': '27062023A',
#   'examen1': 490.04,
#   'examen2': 465.0,
#   'nombre': 'ANCCASI CASAVILCA KEVIN WILLIAMS',
#   'total': 955.04},
#  {'codigo': '27142194B',
#   'examen1': 522.64,
#   'examen2': 546.0,
#   'nombre': 'ANCCO HUACCACHI ANTONI YONI',
#   'total': 1068.64},
#  {'codigo': '2724171B',
#   'examen1': 392.72,
#   'examen2': 153.0,
#   'nombre': 'ANCCO PALOMINO ROCI LUZ',
#   'total': 545.72},
#  {'codigo': '27330176J',
#   'examen1': 391.32,
#   'examen2': 420.0,
#   'nombre': 'ANCHAYHUA RAMOS JORGE LUIS',
#   'total': 811.32},
#  {'codigo': '27460183B',
#   'examen1': 442.72,
#   'examen2': 357.0,
#   'nombre': 'ANCHI DUEÑAS HAIRTON ANDREE',
#   'total': 799.72},
#  {'codigo': '2720195A',
#   'examen1': 439.0,
#   'examen2': 453.0,
#   'nombre': 'ANCHIRAICO SOTO ENGELS RODOLF',
#   'total': 892.0},
#  {'codigo': '2720324G',
#   'examen1': 298.28,
#   'examen2': 132.0,
#   'nombre': 'ANCHITA LÓPEZ ALBERT MOISÉS',
#   'total': 430.28},
#  {'codigo': '2775153G',
#   'examen1': 373.8,
#   'examen2': 120.0,
#   'nombre': 'ANCO BLAS LIZET GILARY',
#   'total': 493.8},
#  {'codigo': '2780282K',
#   'examen1': 526.56,
#   'examen2': 300.0,
#   'nombre': 'ANDAZABAL REBAZA MARCO ANTONIO',
#   'total': 826.56},
#  {'codigo': '2792117I',
#   'examen1': 433.72,
#   'examen2': 477.0,
#   'nombre': 'ANDIA ARTIAGA RICARDO JOSUE',
#   'total': 910.72},
#  {'codigo': '28010384H',
#   'examen1': 454.56,
#   'examen2': 267.0,
#   'nombre': 'ANDIA ROMERO GENARO',
#   'total': 721.56},
#  {'codigo': '2814095D',
#   'examen1': 483.08,
#   'examen2': 246.0,
#   'nombre': 'ANDIA TITO LUIS RODRIGO',
#   'total': 729.08},
#  {'codigo': '28242041H',
#   'examen1': 406.04,
#   'examen2': 207.0,
#   'nombre': 'ANDRADE ALCCAHUA EBERTH FABIAN',
#   'total': 613.04},
#  {'codigo': '2833205C',
#   'examen1': 367.52,
#   'examen2': 186.0,
#   'nombre': 'ANDRADE CAJA JEZABEL PAOLA',
#   'total': 553.52},
#  {'codigo': '28451557A',
#   'examen1': 511.0,
#   'examen2': 198.0,
#   'nombre': 'ANDRADE ORDOÑEZ PAMELA NATALY',
#   'total': 709.0},
#  {'codigo': '28532301K',
#   'examen1': 485.92,
#   'examen2': 330.0,
#   'nombre': 'ANDRADE PARIONA LEONID ANGEELO',
#   'total': 815.92},
#  {'codigo': '2820296I',
#   'examen1': 447.6,
#   'examen2': 444.0,
#   'nombre': 'ANDRADE QUISPE JOSEPH ROBERTO',
#   'total': 891.6},
#  {'codigo': '28732383I',
#   'examen1': 371.84,
#   'examen2': 93.0,
#   'nombre': 'ANDRADE RUIZ MARGARITA ROSA DEL CIELO',
#   'total': 464.84},
#  {'codigo': '28810334J',
#   'examen1': 369.8,
#   'examen2': 249.0,
#   'nombre': 'ANDRADE SAAVEDRA GUIDO DANIEL',
#   'total': 618.8},
#  {'codigo': '2894191H',
#   'examen1': 448.36,
#   'examen2': 369.0,
#   'nombre': 'ANDRADE VARGAS JACOB ISAIS',
#   'total': 817.36},
#  {'codigo': '29081009K',
#   'examen1': 507.84,
#   'examen2': 456.0,
#   'nombre': 'ANDRES ALMONACID MARCELO RUBEN',
#   'total': 963.84},
#  {'codigo': '2912017F',
#   'examen1': 416.08,
#   'examen2': 198.0,
#   'nombre': 'ANDRES PALACIOS FIORELLA MILAGROS',
#   'total': 614.08},
#  {'codigo': '29241900A',
#   'examen1': 453.96,
#   'examen2': 315.0,
#   'nombre': 'ANGELES BARAZORDA JEAN PIER RENZO',
#   'total': 768.96},
#  {'codigo': '2934188G',
#   'examen1': 471.88,
#   'examen2': 237.0,
#   'nombre': 'ÁNGELES CASTILLO JUAN ANHLES',
#   'total': 708.88},
#  {'codigo': '29431475E',
#   'examen1': 432.84,
#   'examen2': 342.0,
#   'nombre': 'ANGELES LEON ANDRES SEBASTIAN',
#   'total': 774.84},
#  {'codigo': '29541577H',
#   'examen1': 434.4,
#   'examen2': 294.0,
#   'nombre': 'ANGELES MAYTA JUAN ALDAIR',
#   'total': 728.4},
#  {'codigo': '2910302J',
#   'examen1': 277.52,
#   'examen2': 9.0,
#   'nombre': 'ANGELES SANCHEZ NICOL DEL PILAR',
#   'total': 286.52},
#  {'codigo': '2974209I',
#   'examen1': 347.84,
#   'examen2': 300.0,
#   'nombre': 'ANGELES VALQUI EDELMIRA',
#   'total': 647.84},
#  {'codigo': '29832242G',
#   'examen1': 274.04,
#   'examen2': 123.0,
#   'nombre': 'ANGULO ORELLANA DIEGO ALBERTO',
#   'total': 397.04},
#  {'codigo': '2992008J',
#   'examen1': 539.32,
#   'examen2': 471.0,
#   'nombre': 'ANGULO PALOMINO JUAN DANIEL',
#   'total': 1010.32},
#  {'codigo': '3002317D',
#   'examen1': 461.64,
#   'examen2': 162.0,
#   'nombre': 'ANGULO SAYAS KEVIN BRANDON',
#   'total': 623.64},
#  {'codigo': '30110382I',
#   'examen1': 353.52,
#   'examen2': 291.0,
#   'nombre': 'ANO QUEJIAS MARYELY',
#   'total': 644.52},
#  {'codigo': '30241042K',
#   'examen1': 427.08,
#   'examen2': 396.0,
#   'nombre': 'ANTAURCO QUISPE CARLOS ALBERTO',
#   'total': 823.08},
#  {'codigo': '30341220J',
#   'examen1': 279.6,
#   'examen2': 189.0,
#   'nombre': 'ANTAY VARGAS SEBASTIAN ANDRES DAMASO',
#   'total': 468.6},
#  {'codigo': '30432344I',
#   'examen1': 442.76,
#   'examen2': 387.0,
#   'nombre': 'ANTAYHUA ORRILLO MAXIMILIANO ADRIAN',
#   'total': 829.76},
#  {'codigo': '3052959DI',
#   'examen1': 316.36,
#   'examen2': 42.0,
#   'nombre': 'ANTEZANA ESCOBAR ZENAIDA ERIKA',
#   'total': 358.36},
#  {'codigo': '3031707G',
#   'examen1': 365.72,
#   'examen2': 375.0,
#   'nombre': 'ANTEZANA YANA JHAN RONALDO',
#   'total': 740.72},
#  {'codigo': '3074177J',
#   'examen1': 353.6,
#   'examen2': 204.0,
#   'nombre': 'ANTONIO POMALLANQUI LARRY FERNANDO',
#   'total': 557.6},
#  {'codigo': '3080341DI',
#   'examen1': 341.96,
#   'examen2': 135.0,
#   'nombre': 'ANTONIO SINCHE BRYAN ELVIS',
#   'total': 476.96},
#  {'codigo': '30940140B',
#   'examen1': 530.16,
#   'examen2': 420.0,
#   'nombre': 'ANTONIO VILCHEZ LUIS FERNANDO',
#   'total': 950.16},
#  {'codigo': '31030120D',
#   'examen1': 472.28,
#   'examen2': 504.0,
#   'nombre': 'ANYACU SELARAYAN CESAR AUGUSTO',
#   'total': 976.28},
#  {'codigo': '3112880A',
#   'examen1': 518.84,
#   'examen2': 321.0,
#   'nombre': 'ANYARIN MANCILLA CARLOS JESÚS',
#   'total': 839.84},
#  {'codigo': '3122573C',
#   'examen1': 363.48,
#   'examen2': 258.0,
#   'nombre': 'ANYOSA FERNANDEZ NEYSER ALVARO',
#   'total': 621.48},
#  {'codigo': '31341982J',
#   'examen1': 432.16,
#   'examen2': 252.0,
#   'nombre': 'AÑAGUARI QUISPE GERALDINE ESTEFANI',
#   'total': 684.16},
#  {'codigo': '3143040B',
#   'examen1': 555.08,
#   'examen2': 456.0,
#   'nombre': 'AÑANCA PAIRAZAMAN ROBERTO JESUS',
#   'total': 1011.08},
#  {'codigo': '31520208E',
#   'examen1': 498.44,
#   'examen2': 273.0,
#   'nombre': 'AÑASCO GUTIERREZ MICHAEL TRUMAN',
#   'total': 771.44},
#  {'codigo': '3110217C',
#   'examen1': 332.92,
#   'examen2': 147.0,
#   'nombre': 'APARICIO AVILA ALDAIR ANTONY',
#   'total': 479.92},
#  {'codigo': '31732240HI',
#   'examen1': 426.84,
#   'examen2': 345.0,
#   'nombre': 'APAZA APAZA LUCIO SERGIO',
#   'total': 771.84},
#  {'codigo': '31841815E',
#   'examen1': 389.6,
#   'examen2': 132.0,
#   'nombre': 'APAZA ARANDA MILAGROS VALERY JAZMYN',
#   'total': 521.6},
#  {'codigo': '3193249A',
#   'examen1': 207.08,
#   'examen2': 213.0,
#   'nombre': 'APAZA CARBAJAL AXELL',
#   'total': 420.08},
#  {'codigo': '3203013BI',
#   'examen1': 461.04,
#   'examen2': 402.0,
#   'nombre': 'APAZA COAQUIRA KAREN MABEL',
#   'total': 863.04},
#  {'codigo': '32120385C',
#   'examen1': 383.92,
#   'examen2': 402.0,
#   'nombre': 'APAZA CONDORI FREDERICK ALDAYR',
#   'total': 785.92},
#  {'codigo': '32240224F',
#   'examen1': 350.4,
#   'examen2': 378.0,
#   'nombre': 'APAZA FALCON YOJHAN DENYLSON',
#   'total': 728.4},
#  {'codigo': '32352401E',
#   'examen1': 222.16,
#   'examen2': 93.0,
#   'nombre': 'APAZA ILLACONZA VICTOR MANUEL',
#   'total': 315.16},
#  {'codigo': '32458003C',
#   'examen1': 409.92,
#   'examen2': 120.0,
#   'nombre': 'APAZA LAYME KIMBERLY   JENNIFFER',
#   'total': 529.92},
#  {'codigo': '32510518F',
#   'examen1': 507.72,
#   'examen2': 222.0,
#   'nombre': 'APAZA MEJIA YAHAIDA',
#   'total': 729.72},
#  {'codigo': '3241033A',
#   'examen1': 441.64,
#   'examen2': 222.0,
#   'nombre': 'APAZA PACHECO BRUCE JEREMY',
#   'total': 663.64},
#  {'codigo': '32740921A',
#   'examen1': 446.24,
#   'examen2': 156.0,
#   'nombre': 'APAZA ROQUE DIEGO ORLANDO',
#   'total': 602.24},
#  {'codigo': '32810155F',
#   'examen1': 390.0,
#   'examen2': 381.0,
#   'nombre': 'APOLINARIO CANO ANTHONY KASUMI',
#   'total': 771.0},
#  {'codigo': '32990023A',
#   'examen1': 389.28,
#   'examen2': 246.0,
#   'nombre': 'APOLINARIO SAENZ LUIS MANUEL',
#   'total': 635.28},
#  {'codigo': '33052028C',
#   'examen1': 455.84,
#   'examen2': 198.0,
#   'nombre': 'APONTE CHAVEZ JUAN JOSE',
#   'total': 653.84},
#  {'codigo': '33141559J',
#   'examen1': 347.44,
#   'examen2': 297.0,
#   'nombre': 'APONTE RODRIGUEZ ERICK JHONATAN',
#   'total': 644.44},
#  {'codigo': '3324113C',
#   'examen1': 554.68,
#   'examen2': 378.0,
#   'nombre': 'APONTE SIMÓN ERICK GUSTAVO',
#   'total': 932.68},
#  {'codigo': '3332019G',
#   'examen1': 504.0,
#   'examen2': 327.0,
#   'nombre': 'APONTE UTANI ALEXANDRA PAOLA',
#   'total': 831.0},
#  {'codigo': '3345161C',
#   'examen1': 399.88,
#   'examen2': 186.0,
#   'nombre': 'APONTE VILCA BELEN AMPARO',
#   'total': 585.88},
#  {'codigo': '33540032E',
#   'examen1': 447.8,
#   'examen2': 492.0,
#   'nombre': 'APOSTOL CANDELA JESUS BRANNI',
#   'total': 939.8},
#  {'codigo': '33641352B',
#   'examen1': 409.88,
#   'examen2': 165.0,
#   'nombre': 'AQUINO FLORES KEVIN ANGELO',
#   'total': 574.88},
#  {'codigo': '3340361J',
#   'examen1': 509.68,
#   'examen2': 441.0,
#   'nombre': 'AQUINO MEDINA KEVIN GUIANFERS',
#   'total': 950.68},
#  {'codigo': '3383243A',
#   'examen1': 201.64,
#   'examen2': 168.0,
#   'nombre': 'AQUINO MEZA DAVID ANTONIO',
#   'total': 369.64},
#  {'codigo': '33910202G',
#   'examen1': 310.32,
#   'examen2': 267.0,
#   'nombre': 'AQUINO MEZA LEONARDO GABRIEL',
#   'total': 577.32},
#  {'codigo': '34060215I',
#   'examen1': 314.44,
#   'examen2': 153.0,
#   'nombre': 'AQUINO OSORIO JENNIFER COREY',
#   'total': 467.44},
#  {'codigo': '34142233I',
#   'examen1': 412.2,
#   'examen2': 252.0,
#   'nombre': 'AQUINO RAMIREZ WILMER ABAD',
#   'total': 664.2},
#  {'codigo': '3423262C',
#   'examen1': 413.72,
#   'examen2': 192.0,
#   'nombre': 'ARA VALLADARES OMAR JUNIOR',
#   'total': 605.72},
#  {'codigo': '34362042DI',
#   'examen1': 154.2,
#   'examen2': 96.0,
#   'nombre': 'ARAGON HINOJOSA DUGLAS',
#   'total': 250.2},
#  {'codigo': '3443255J',
#   'examen1': 401.64,
#   'examen2': 234.0,
#   'nombre': 'ARAMBURÚ BENAVENTE ADRIAN VICTOR',
#   'total': 635.64},
#  {'codigo': '34551998A',
#   'examen1': 363.44,
#   'examen2': 99.0,
#   'nombre': 'ARANA VILCA GRACE ALEXANDRA',
#   'total': 462.44},
#  {'codigo': '3462065J',
#   'examen1': 356.56,
#   'examen2': 36.0,
#   'nombre': 'ARANCIBIA TASAYCO LUIS GERARDO',
#   'total': 392.56},
#  {'codigo': '3432278E',
#   'examen1': 506.96,
#   'examen2': 198.0,
#   'nombre': 'ARANGO HUAMAN LESLIE CONSUELO',
#   'total': 704.96},
#  {'codigo': '34862184KI',
#   'examen1': 373.28,
#   'examen2': 267.0,
#   'nombre': 'ARANGO LEON ELIAN FRANCISCO',
#   'total': 640.28},
#  {'codigo': '34920113C',
#   'examen1': 415.12,
#   'examen2': 348.0,
#   'nombre': 'ARANGO LEÓN NICOLL BETSY',
#   'total': 763.12},
#  {'codigo': '35032643B',
#   'examen1': 406.64,
#   'examen2': 309.0,
#   'nombre': 'ARANGO NUÑEZ CARLOS ALBERTO',
#   'total': 715.64},
#  {'codigo': '35152054F',
#   'examen1': 511.8,
#   'examen2': 321.0,
#   'nombre': 'ARANGUREN BAUTISTA CRISTIAN RODRIGO',
#   'total': 832.8},
#  {'codigo': '35240058J',
#   'examen1': 468.68,
#   'examen2': 282.0,
#   'nombre': 'ARANIBAR QUISPE MAX',
#   'total': 750.68},
#  {'codigo': '35342192C',
#   'examen1': 390.88,
#   'examen2': 144.0,
#   'nombre': 'ARANYA JUSTINIANI JESUS',
#   'total': 534.88},
#  {'codigo': '35441531F',
#   'examen1': 163.16,
#   'examen2': 168.0,
#   'nombre': 'ARANZAMENDI PEREZ CARMEN ROSA',
#   'total': 331.16},
#  {'codigo': '35541988G',
#   'examen1': 438.04,
#   'examen2': 366.0,
#   'nombre': 'ARAOS SILVA CRISTIAN MANUEL',
#   'total': 804.04},
#  {'codigo': '35642092K',
#   'examen1': 300.84,
#   'examen2': 249.0,
#   'nombre': 'ARAPA MONROY JARED SHAKIRA',
#   'total': 549.84},
#  {'codigo': '3551755H',
#   'examen1': 370.76,
#   'examen2': 105.0,
#   'nombre': 'ARATA YATACO SEBASTIAN',
#   'total': 475.76},
#  {'codigo': '35810229F',
#   'examen1': 317.72,
#   'examen2': 210.0,
#   'nombre': 'ARAUCO BADA SEBASTIAN IVÁN',
#   'total': 527.72},
#  {'codigo': '35952035C',
#   'examen1': 513.12,
#   'examen2': 315.0,
#   'nombre': 'ARAUCO GÓMEZ ALFREDO BELTRÁN',
#   'total': 828.12},
#  {'codigo': '36041259A',
#   'examen1': 313.04,
#   'examen2': 60.0,
#   'nombre': 'ARAUJO AGUILAR GARY LOREN',
#   'total': 373.04},
#  {'codigo': '36130060F',
#   'examen1': 484.44,
#   'examen2': 390.0,
#   'nombre': 'ARAUJO DEL RIO JAIRO ANDERSON',
#   'total': 874.44},
#  {'codigo': '36210325K',
#   'examen1': 533.64,
#   'examen2': 285.0,
#   'nombre': 'ARAUJO GAMBOA NICOLY SOLEDAD',
#   'total': 818.64},
#  {'codigo': '36340286GI',
#   'examen1': 343.56,
#   'examen2': 213.0,
#   'nombre': 'ARAUJO MALDONADO NICOLE DE LOS ANGELES',
#   'total': 556.56},
#  {'codigo': '36442068G',
#   'examen1': 477.32,
#   'examen2': 183.0,
#   'nombre': 'ARCA AMARO JESÚS DIÓGENES JORGE',
#   'total': 660.32},
#  {'codigo': '36532515H',
#   'examen1': 341.0,
#   'examen2': 189.0,
#   'nombre': 'ARCE BENDEZU LUIS MANUEL',
#   'total': 530.0},
#  {'codigo': '36640138E',
#   'examen1': 418.96,
#   'examen2': 120.0,
#   'nombre': 'ARCE LINARES SEBASTIAN RODRIGO',
#   'total': 538.96},
#  {'codigo': '3651721I',
#   'examen1': 472.56,
#   'examen2': 363.0,
#   'nombre': 'ARCONDO CCORIMANYA JHON DAVID',
#   'total': 835.56},
#  {'codigo': '3684200D',
#   'examen1': 359.12,
#   'examen2': 219.0,
#   'nombre': 'ARECHE LAURA PAOLA MARISOL',
#   'total': 578.12},
#  {'codigo': '36930105J',
#   'examen1': 515.24,
#   'examen2': 414.0,
#   'nombre': 'ARELLANO ARNAO ALEXIS MOSUE',
#   'total': 929.24},
#  {'codigo': '3032424D',
#   'examen1': 363.0,
#   'examen2': 177.0,
#   'nombre': 'ARELLANO HERRERA PEDRO GEORGINO',
#   'total': 540.0},
#  {'codigo': '3190006A',
#   'examen1': 311.76,
#   'examen2': 162.0,
#   'nombre': 'ARELLANO MONTES MARCO CARLOS',
#   'total': 473.76},
#  {'codigo': '3241836G',
#   'examen1': 438.76,
#   'examen2': 204.0,
#   'nombre': 'ARELLANO SALCEDO ROSAYCELA DIGNA',
#   'total': 642.76},
#  {'codigo': '3330016E',
#   'examen1': 501.48,
# ...
#  {'codigo': '87841717A',
#   'examen1': 440.84,
#   'examen2': 450.0,
#   'nombre': 'CANCHARI PERALES RICHARD MARCELO',
#   'total': 890.84},
#  {'codigo': '87932661K',
#   'examen1': 398.48,
#   'examen2': 306.0,
#   'nombre': 'CANCHAYA CRISTOBAL LUIS FAUSTO',
#   'total': 704.48},
#  {'codigo': '88020043A',
#   'examen1': 426.64,
#   'examen2': 357.0,
#   'nombre': 'CANCHAYA LIMACHI GLORIA JHASMIN',
#   'total': 783.64},
#  {'codigo': '88120710F',
#   'examen1': 268.16,
#   'examen2': 447.0,
#   'nombre': 'CANCINO ZAMORA JOAN GLOISER',
#   'total': 715.16},
#  {'codigo': '88231959JI',
#   'examen1': 450.0,
#   'examen2': 207.0,
#   'nombre': 'CANDELA APAZA RODRIGO',
#   'total': 657.0},
#  {'codigo': '883303II',
#   'examen1': 486.2,
#   'examen2': 570.0,
#   'nombre': 'CANDELA CHILLCCE JUNIOR SMITH',
#   'total': 1056.2},
#  {'codigo': '88420288D',
#   'examen1': 328.16,
#   'examen2': 333.0,
#   'nombre': 'CANDIO CHAVEZ GIANCARLO',
#   'total': 661.16},
#  {'codigo': '88520686F',
#   'examen1': 375.24,
#   'examen2': 270.0,
#   'nombre': 'CANICANI CCAHUANA RUBÉN DARIO',
#   'total': 645.24},
#  {'codigo': '88632081A',
#   'examen1': 279.52,
#   'examen2': 216.0,
#   'nombre': 'CANO ANDRADE ANDRES ALEXANDER',
#   'total': 495.52},
#  {'codigo': '88732476A',
#   'examen1': 411.84,
#   'examen2': 372.0,
#   'nombre': 'CANO CORONADO STEVEN ISAIAS CRISTOPHER',
#   'total': 783.84},
#  {'codigo': '88810015I',
#   'examen1': 519.64,
#   'examen2': 447.0,
#   'nombre': 'CANO DIAZ JOEL BENJAMIN',
#   'total': 966.64},
#  {'codigo': '88962971E',
#   'examen1': 268.52,
#   'examen2': 105.0,
#   'nombre': 'CANORIO ANCHIRAICO GABRIEL ANTONIO',
#   'total': 373.52},
#  {'codigo': '89030388H',
#   'examen1': 496.56,
#   'examen2': 315.0,
#   'nombre': 'CANTA FIESTAS ANDRES FERNANDO',
#   'total': 811.56},
#  {'codigo': '89140884D',
#   'examen1': 397.44,
#   'examen2': 117.0,
#   'nombre': 'CANTARO LAZARO MANUEL ALONSO',
#   'total': 514.44},
#  {'codigo': '89262823C',
#   'examen1': 294.88,
#   'examen2': 135.0,
#   'nombre': 'CANTEÑO BORJA MEUJAEL',
#   'total': 429.88},
#  {'codigo': '89340121J',
#   'examen1': 242.24,
#   'examen2': 63.0,
#   'nombre': 'CANTO MAGALLANES JOSÉ ANTONIO',
#   'total': 305.24},
#  {'codigo': '89430234I',
#   'examen1': 325.28,
#   'examen2': 171.0,
#   'nombre': 'CANTORAL GUERRA FIORELLA',
#   'total': 496.28},
#  {'codigo': '89520737E',
#   'examen1': 345.8,
#   'examen2': 255.0,
#   'nombre': 'CANTORAL VELASQUEZ ARTURO',
#   'total': 600.8},
#  {'codigo': '89640092G',
#   'examen1': 508.16,
#   'examen2': 585.0,
#   'nombre': 'CAÑARI ALTAMIRANO JULIO CESAR',
#   'total': 1093.16},
#  {'codigo': '89741258G',
#   'examen1': 343.88,
#   'examen2': 228.0,
#   'nombre': 'CAÑARI VASQUEZ GARI ALEXANDRO',
#   'total': 571.88},
#  {'codigo': '89832168I',
#   'examen1': 463.08,
#   'examen2': 363.0,
#   'nombre': 'CAPARI ANCO BRUCCE ALBERTO',
#   'total': 826.08},
#  {'codigo': '89941533E',
#   'examen1': 531.8,
#   'examen2': 225.0,
#   'nombre': 'CAPCHA BEDOYA CAROLEI JESSIE',
#   'total': 756.8},
#  {'codigo': '90020224D',
#   'examen1': 365.68,
#   'examen2': 402.0,
#   'nombre': 'CAPCHA CAMPOS HIMBLER RENATO',
#   'total': 767.68},
#  {'codigo': '90141303I',
#   'examen1': 302.52,
#   'examen2': 192.0,
#   'nombre': 'CAPCHA ENCISO CESAR RUBEN',
#   'total': 494.52},
#  {'codigo': '90250083II',
#   'examen1': 387.44,
#   'examen2': 261.0,
#   'nombre': 'CAPCHA GUTIERREZ PILAR VICTORIA',
#   'total': 648.44},
#  {'codigo': '90330255KI',
#   'examen1': 490.08,
#   'examen2': 351.0,
#   'nombre': 'CAPCHA HUIPER GIANFRANCO RICHARD',
#   'total': 841.08},
#  {'codigo': '90441109K',
#   'examen1': 309.2,
#   'examen2': 15.0,
#   'nombre': 'CAPCHA PAITAMPOMA ALEX ANDERSON',
#   'total': 324.2},
#  {'codigo': '90520425DI',
#   'examen1': 279.4,
#   'examen2': 78.0,
#   'nombre': 'CAPCHA PUZA JUAN ALFREDO',
#   'total': 357.4},
#  {'codigo': '90662328B',
#   'examen1': 281.08,
#   'examen2': 1.0,
#   'nombre': 'CAPIA CCAMA ALEX JESUS',
#   'total': 282.08},
#  {'codigo': '90762095F',
#   'examen1': 367.28,
#   'examen2': 69.0,
#   'nombre': 'CAQUI MENDOZA MICHEL ANTONY',
#   'total': 436.28},
#  {'codigo': '90851944E',
#   'examen1': 324.08,
#   'examen2': 153.0,
#   'nombre': 'CARACAMO LOPEZ MILTON JAHIR',
#   'total': 477.08},
#  {'codigo': '90931994A',
#   'examen1': 358.0,
#   'examen2': 168.0,
#   'nombre': 'CARBAJAL ALLPACCA ROMAN GONZALO',
#   'total': 526.0},
#  {'codigo': '91041283E',
#   'examen1': 498.24,
#   'examen2': 264.0,
#   'nombre': 'CARBAJAL GUERRERO JOSUÉ RENÉ',
#   'total': 762.24},
#  {'codigo': '91160243K',
#   'examen1': 380.12,
#   'examen2': 186.0,
#   'nombre': 'CARBAJAL LIZARME BREEDERS',
#   'total': 566.12},
#  {'codigo': '91240067I',
#   'examen1': 422.32,
#   'examen2': 267.0,
#   'nombre': 'CARBAJAL MOSCOSO KEM GIUSSEPPE',
#   'total': 689.32},
#  {'codigo': '913367II',
#   'examen1': 555.24,
#   'examen2': 528.0,
#   'nombre': 'CARBAJAL PECHO KATERYN LISBETH',
#   'total': 1083.24},
#  {'codigo': '91410476F',
#   'examen1': 396.96,
#   'examen2': 255.0,
#   'nombre': 'CARBAJAL PEDRAZA EDSON RAUL',
#   'total': 651.96},
#  {'codigo': '91530288E',
#   'examen1': 485.88,
#   'examen2': 309.0,
#   'nombre': 'CARBAJAL ROBLES SHERLY DAYSI',
#   'total': 794.88},
#  {'codigo': '91632429G',
#   'examen1': 399.0,
#   'examen2': 330.0,
#   'nombre': 'CARBAJAL SULLCA JHONATAN  JOEL',
#   'total': 729.0},
#  {'codigo': '932224I',
#   'examen1': 344.32,
#   'examen2': 48.0,
#   'nombre': 'CARBAJAL VILELA AARON DANIEL',
#   'total': 392.32},
#  {'codigo': '91842251G',
#   'examen1': 380.84,
#   'examen2': 45.0,
#   'nombre': 'CARBONEL AGUILAR JHARED ISAAC',
#   'total': 425.84},
#  {'codigo': '91941051J',
#   'examen1': 415.68,
#   'examen2': 327.0,
#   'nombre': 'CARBONEL PARDO VICTOR MANUEL',
#   'total': 742.68},
#  {'codigo': '92010389K',
#   'examen1': 304.0,
#   'examen2': 105.0,
#   'nombre': 'CARBONEL VERA WILLY ALBERTO',
#   'total': 409.0},
#  {'codigo': '92150065K',
#   'examen1': 450.0,
#   'examen2': 132.0,
#   'nombre': 'CARBONELL LEON PATRICIA BEATRIZ',
#   'total': 582.0},
#  {'codigo': '92230123H',
#   'examen1': 410.64,
#   'examen2': 342.0,
#   'nombre': 'CARCASI TICLAHUANCA RONALD DANIEL',
#   'total': 752.64},
#  {'codigo': '92341525K',
#   'examen1': 464.8,
#   'examen2': 522.0,
#   'nombre': 'CÁRDENAS ANTÓN ENZO ENRIQUE',
#   'total': 986.8},
#  {'codigo': '92410054I',
#   'examen1': 278.16,
#   'examen2': 273.0,
#   'nombre': 'CARDENAS ASTUPILLO JUAN',
#   'total': 551.16},
#  {'codigo': '925109A',
#   'examen1': 387.04,
#   'examen2': 159.0,
#   'nombre': 'CARDENAS BARTA ANDREA SARA',
#   'total': 546.04},
#  {'codigo': '92610485E',
#   'examen1': 516.44,
#   'examen2': 378.0,
#   'nombre': 'CARDENAS CABRERA PEDRO JORGE SAMUEL',
#   'total': 894.44},
#  {'codigo': '92731662C',
#   'examen1': 476.2,
#   'examen2': 348.0,
#   'nombre': 'CÁRDENAS CHIPANA ANA PATRICIA',
#   'total': 824.2},
#  {'codigo': '92862470G',
#   'examen1': 305.64,
#   'examen2': 126.0,
#   'nombre': 'CARDENAS CORONADO MIGUEL ANGEL',
#   'total': 431.64},
#  {'codigo': '92931351G',
#   'examen1': 342.48,
#   'examen2': 264.0,
#   'nombre': 'CARDENAS JAIMES MARCO ANTONIO',
#   'total': 606.48},
#  {'codigo': '93058044K',
#   'examen1': 378.76,
#   'examen2': 120.0,
#   'nombre': 'CARDENAS LUCIANO YULISSA AURELIA',
#   'total': 498.76},
#  {'codigo': '93142143J',
#   'examen1': 482.32,
#   'examen2': 264.0,
#   'nombre': 'CARDENAS MIRANDA ROSALINA',
#   'total': 746.32},
#  {'codigo': '93232291K',
#   'examen1': 437.4,
#   'examen2': 531.0,
#   'nombre': 'CARDENAS MUÑOZ JOHIL NICK',
#   'total': 968.4},
#  {'codigo': '93331973J',
#   'examen1': 372.92,
#   'examen2': 150.0,
#   'nombre': 'CARDENAS PAREJA CHRISTOFER RICHARD',
#   'total': 522.92},
#  {'codigo': '93451587B',
#   'examen1': 342.96,
#   'examen2': 171.0,
#   'nombre': 'CARDENAS QUINTO ROBERTA MAILY',
#   'total': 513.96},
#  {'codigo': '93562398H',
#   'examen1': 466.28,
#   'examen2': 174.0,
#   'nombre': 'CÁRDENAS RAMIREZ JEAN CARLO',
#   'total': 640.28},
#  {'codigo': '93631726J',
#   'examen1': 473.2,
#   'examen2': 411.0,
#   'nombre': 'CARDENAS SACCACO AARON FERNANDO',
#   'total': 884.2},
#  {'codigo': '93740087FI',
#   'examen1': 365.0,
#   'examen2': 102.0,
#   'nombre': 'CÁRDENAS VALLADOLID NATHALY NICOLE',
#   'total': 467.0},
#  {'codigo': '93841758KI',
#   'examen1': 235.4,
#   'examen2': 96.0,
#   'nombre': 'CARDENAS VASQUEZ ERIKA',
#   'total': 331.4},
#  {'codigo': '93932510E',
#   'examen1': 340.16,
#   'examen2': 42.0,
#   'nombre': 'CARDENAS VILLAGARAY BRYAN GROVER',
#   'total': 382.16},
#  {'codigo': '94062255G',
#   'examen1': 401.04,
#   'examen2': 219.0,
#   'nombre': 'CARHUACUSMA INCA CARLOS DANIEL',
#   'total': 620.04},
#  {'codigo': '94141745C',
#   'examen1': 325.52,
#   'examen2': 60.0,
#   'nombre': 'CARHUALLANQUI ARCOS AARON ANGEL',
#   'total': 385.52},
#  {'codigo': '94262689G',
#   'examen1': 399.76,
#   'examen2': 249.0,
#   'nombre': 'CARHUALLAY ALMONACID JOHN NICOLAS',
#   'total': 648.76},
#  {'codigo': '94332041GI',
#   'examen1': 357.4,
#   'examen2': 192.0,
#   'nombre': 'CARHUANCHO ALMANZA DANIEL JUSTO',
#   'total': 549.4},
#  {'codigo': '94462519I',
#   'examen1': 473.56,
#   'examen2': 327.0,
#   'nombre': 'CARHUANCHO FABIAN MARCO AURELIO',
#   'total': 800.56},
#  {'codigo': '94562240K',
#   'examen1': 476.24,
#   'examen2': 234.0,
#   'nombre': 'CARHUANCHO FALCON WILSON',
#   'total': 710.24},
#  {'codigo': '94632122G',
#   'examen1': 417.08,
#   'examen2': 204.0,
#   'nombre': 'CARHUANCHO GUTIERREZ DANIEL  JEANMARCO',
#   'total': 621.08},
#  {'codigo': '947449D',
#   'examen1': 332.64,
#   'examen2': 1.0,
#   'nombre': 'CARHUANCHO YNCIO LEANDRO JAVIER',
#   'total': 333.64},
#  {'codigo': '94862824H',
#   'examen1': 519.64,
#   'examen2': 267.0,
#   'nombre': 'CARHUAS CORDOVA JOSEPH KENNYI',
#   'total': 786.64},
#  {'codigo': '94920293E',
#   'examen1': 378.08,
#   'examen2': 339.0,
#   'nombre': 'CARHUAS ROMERO ERICK JESUS',
#   'total': 717.08},
#  {'codigo': '95031497A',
#   'examen1': 428.36,
#   'examen2': 330.0,
#   'nombre': 'CARHUAS ROMERO JHON JESUS',
#   'total': 758.36},
#  {'codigo': '95131503C',
#   'examen1': 415.84,
#   'examen2': 252.0,
#   'nombre': 'CARHUAS ROMERO WILLIAMS JESUS',
#   'total': 667.84},
#  {'codigo': '952403C',
#   'examen1': 325.44,
#   'examen2': 504.0,
#   'nombre': 'CARHUATANTA FUÑO DANIEL ANGEL',
#   'total': 829.44},
#  {'codigo': '95362590G',
#   'examen1': 492.52,
#   'examen2': 231.0,
#   'nombre': 'CARHUATOCTO FLORES WILDER CESAR',
#   'total': 723.52},
#  {'codigo': '95441158D',
#   'examen1': 0.0,
#   'examen2': 0.0,
#   'nombre': 'CARHUAVILCA RAFAEL ANTONIO ALEXANDER',
#   'total': 0.0},
#  {'codigo': '95551790J',
#   'examen1': 433.64,
#   'examen2': 204.0,
#   'nombre': 'CARHUAYAL ALVAREZ SAIRA MARITZA',
#   'total': 637.64},
#  {'codigo': '95620765G',
#   'examen1': 400.52,
#   'examen2': 156.0,
#   'nombre': 'CARLOS MANDUJANO KELVIN YIM',
#   'total': 556.52},
#  {'codigo': '95780021K',
#   'examen1': 383.68,
#   'examen2': 318.0,
#   'nombre': 'CARLOS SALVADOR ALEXANDRA C',
#   'total': 701.68},
#  {'codigo': '95862745G',
#   'examen1': 462.72,
#   'examen2': 426.0,
#   'nombre': 'CARLOS SUAREZ JEAN PIERE',
#   'total': 888.72},
#  {'codigo': '95940331I',
#   'examen1': 262.48,
#   'examen2': 63.0,
#   'nombre': 'CARMEN YON KEVIN GONZALO',
#   'total': 325.48},
#  {'codigo': '96031777B',
#   'examen1': 246.52,
#   'examen2': 30.0,
#   'nombre': 'CARNERO PÉREZ ALISSA DANIELA',
#   'total': 276.52},
#  {'codigo': '96132363AI',
#   'examen1': 422.96,
#   'examen2': 126.0,
#   'nombre': 'CARO CONTRERAS ANDREA MELANIE',
#   'total': 548.96},
#  {'codigo': '96262700J',
#   'examen1': 424.84,
#   'examen2': 390.0,
#   'nombre': 'CARO SANCHEZ JOSE MANUEL',
#   'total': 814.84},
#  {'codigo': '96310076E',
#   'examen1': 321.52,
#   'examen2': 405.0,
#   'nombre': 'CARO SANDOVAL JOSEPH MOISES',
#   'total': 726.52},
#  {'codigo': '96460301J',
#   'examen1': 402.24,
#   'examen2': 279.0,
#   'nombre': 'CARPIO PALOMINO LEONCIO JOSUE',
#   'total': 681.24},
#  {'codigo': '96540990B',
#   'examen1': 556.08,
#   'examen2': 564.0,
#   'nombre': 'CARQUIN SANTILLAN YANSEN JOSSET',
#   'total': 1120.08},
#  {'codigo': '96620802D',
#   'examen1': 374.08,
#   'examen2': 252.0,
#   'nombre': 'CARRANZA CAPCHA KEVIN',
#   'total': 626.08},
#  {'codigo': '96740097J',
#   'examen1': 386.0,
#   'examen2': 231.0,
#   'nombre': 'CARRANZA FENTE ANTHONY CHRISTIAN',
#   'total': 617.0},
#  {'codigo': '96862926J',
#   'examen1': 188.72,
#   'examen2': 24.0,
#   'nombre': 'CARRANZA GARAY RUBEN BRANDY',
#   'total': 212.72},
#  {'codigo': '96941001A',
#   'examen1': 486.04,
#   'examen2': 186.0,
#   'nombre': 'CARRANZA INGA SOFÍA NUWA',
#   'total': 672.04},
#  {'codigo': '97020741A',
#   'examen1': 324.84,
#   'examen2': 348.0,
#   'nombre': 'CARRANZA PAREDES ANTHONY DAVID',
#   'total': 672.84},
#  {'codigo': '97141579G',
#   'examen1': 404.92,
#   'examen2': 258.0,
#   'nombre': 'CARRASCO ARCIBIA FERNANDO',
#   'total': 662.92},
#  {'codigo': '97260228F',
#   'examen1': 315.72,
#   'examen2': 339.0,
#   'nombre': 'CARRASCO CASTRO ALDAHIR',
#   'total': 654.72},
#  {'codigo': '97363126JI',
#   'examen1': 431.6,
#   'examen2': 507.0,
#   'nombre': 'CARRASCO HINOSTROZA CARLOS NESTOR',
#   'total': 938.6},
#  {'codigo': '97458049E',
#   'examen1': 341.8,
#   'examen2': 102.0,
#   'nombre': 'CARRASCO MARTINEZ ARNOLD IVAN',
#   'total': 443.8},
#  {'codigo': '97541720C',
#   'examen1': 443.84,
#   'examen2': 255.0,
#   'nombre': 'CARRASCO ROJAS XIMENA ALEXANDRA',
#   'total': 698.84},
#  {'codigo': '97620809F',
#   'examen1': 347.24,
#   'examen2': 174.0,
#   'nombre': 'CARRASCO RONCAL ALLEN ANTONIO',
#   'total': 521.24},
#  {'codigo': '97758062G',
#   'examen1': 366.24,
#   'examen2': 315.0,
#   'nombre': 'CARRASCO SANCHO DIANA CAROLINA',
#   'total': 681.24},
#  {'codigo': '97840237C',
#   'examen1': 535.96,
#   'examen2': 441.0,
#   'nombre': 'CARRERA TORRES JOSEPH MARTÍN',
#   'total': 976.96},
#  {'codigo': '97950091CI',
#   'examen1': 330.8,
#   'examen2': 33.0,
#   'nombre': 'CARRETERO TORRES ELIZABETH LUCY',
#   'total': 363.8},
#  {'codigo': '98031380C',
#   'examen1': 233.88,
#   'examen2': 201.0,
#   'nombre': 'CARRILLO CHAVEZ RONAL',
#   'total': 434.88},
#  {'codigo': '98132503E',
#   'examen1': 576.76,
#   'examen2': 387.0,
#   'nombre': 'CARRILLO COAQUIRA ALEJANDRA GIANNELA',
#   'total': 963.76},
#  {'codigo': '98252200E',
#   'examen1': 405.16,
#   'examen2': 414.0,
#   'nombre': 'CARRILLO GUEVARA EDWARD REY',
#   'total': 819.16},
#  {'codigo': '98310190H',
#   'examen1': 349.96,
#   'examen2': 33.0,
#   'nombre': 'CARRILLO HERRERA LESLY ALESA',
#   'total': 382.96},
#  {'codigo': '98420390D',
#   'examen1': 436.04,
#   'examen2': 273.0,
#   'nombre': 'CARRILLO LAUREANO CESAR FERNANDO',
#   'total': 709.04},
#  {'codigo': '98560367I',
#   'examen1': 473.04,
#   'examen2': 468.0,
#   'nombre': 'CARRILLO ROMERO ALEJANDRO JOAQUIN',
#   'total': 941.04},
#  {'codigo': '98610237KI',
#   'examen1': 489.08,
#   'examen2': 369.0,
#   'nombre': 'CARRION ALALUNA JHONATAN ALEXANDER',
#   'total': 858.08},
#  {'codigo': '98760385G',
#   'examen1': 491.56,
#   'examen2': 387.0,
#   'nombre': 'CARRIÓN ALMENDRADES ESSLY KENNEDY',
#   'total': 878.56},
#  {'codigo': '98832209D',
#   'examen1': 336.52,
#   'examen2': 177.0,
#   'nombre': 'CARRIÓN BARBOZA JORDAN ABRAHAM',
#   'total': 513.52},
#  {'codigo': '98932295I',
#   'examen1': 483.68,
#   'examen2': 354.0,
#   'nombre': 'CARRIÓN CCOICCA EDGAR FERNANDO',
#   'total': 837.68},
#  {'codigo': '99040932JI',
#   'examen1': 314.92,
#   'examen2': 45.0,
#   'nombre': 'CARRION ESPINOZA NICOLE ESTEFANY',
#   'total': 359.92},
#  {'codigo': '99160276E',
#   'examen1': 460.28,
#   'examen2': 459.0,
#   'nombre': 'CARRIÓN HUARIPATA GIAMPIER ALFONSO',
#   'total': 919.28},
#  {'codigo': '99230250H',
#   'examen1': 404.56,
#   'examen2': 450.0,
#   'nombre': 'CARRION ORE FERNANDO AUGUSTO',
#   'total': 854.56},
#  {'codigo': '99320422K',
#   'examen1': 255.0,
#   'examen2': 36.0,
#   'nombre': 'CARRION PÉREZ ANDRES ANYELO',
#   'total': 291.0},
#  {'codigo': '99442048J',
#   'examen1': 433.16,
#   'examen2': 384.0,
#   'nombre': 'CARRION SALAS ADRIAN ALCIDES',
#   'total': 817.16},
#  {'codigo': '99541690F',
#   'examen1': 287.04,
#   'examen2': 156.0,
#   'nombre': 'CARTOLÍN PÉREZ MIGUEL EDUARDO',
#   'total': 443.04},
#  {'codigo': '99660217HI',
#   'examen1': 524.96,
#   'examen2': 375.0,
#   'nombre': 'CARTY MORANTE ADRIAN ENRIQUE',
#   'total': 899.96},
#  {'codigo': '99720258C',
#   'examen1': 405.52,
#   'examen2': 303.0,
#   'nombre': 'CASA QUISPE SOLANGE TERESA',
#   'total': 708.52},
#  {'codigo': '998410B',
#   'examen1': 548.84,
#   'examen2': 261.0,
#   'nombre': 'CASA RUNTO DIEGO JAVIER',
#   'total': 809.84},
#  {'codigo': '99942081B',
#   'examen1': 345.56,
#   'examen2': 303.0,
#   'nombre': 'CASAFRANCA ARCE LISETH',
#   'total': 648.56},
#  {'codigo': '100040203DI',
#   'examen1': 309.64,
#   'examen2': 324.0,
#   'nombre': 'CASAFRANCA VILCA DEYVIS',
#   'total': 633.64},
#  ...]

# %%
data_final = pd.DataFrame(TOTAL)
data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6178 entries, 0 to 6177
# Data columns (total 5 columns):
# codigo     6178 non-null object
# examen1    6178 non-null float64
# examen2    6178 non-null float64
# nombre     6178 non-null object
# total      6178 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 241.4+ KB

# %%
data_final
# Out:
#            codigo  examen1  examen2                               nombre  \
# 0          51897D   446.08     75.0     ABANTO ARRIOLA STEPHANIE GIOVANA
# 1          30346D   210.52      1.0        ABANTO OCMIN MARTIN GUILLERMO
# 2          41901F   559.72    240.0            ABARCA TINEO EDGAR JUNIOR
# 3          41032G   183.48    174.0        ABARCA VILLANUEVA PILAR MAURA
# 4          62514F   342.12    180.0           ABATE DOMINGUEZ JOEL SMITH
# 5          42154H   265.08     27.0            ABERGA BELLIDO GIAN PIERO
# 6          41919F   297.40    363.0              ABREGO CRUZ LUIS MIGUEL
# 7          50048G   312.60     84.0           ABREGO HILARIO SAMANTA LEA
# 8          40263F   505.84    312.0        ABREGO YUCRA JENNIFER MARITZA
# 9          81001K   429.68    351.0        ABREGU CHILQUILLO AILTON ALEX
# 10         41613K   506.52    399.0      ABURTO RAMÍREZ ALEXANDER MANUEL
# 11         42077F   432.24     12.0        ACASIETE ARIAS ERNESTO ANIBAL
# 12         40022A   522.12    249.0           ACERO CARRION JULIO MIGUEL
# 13         10484K   578.60    267.0        ACERO RODRIGUEZ SHIRLEY MERCY
# 14         81002K   460.96    282.0             ACEVEDO AGUERO GIAN POOL
# 15         41291J   411.52     18.0              ACEVEDO CALLE GUILLERMO
# 16         32348G   395.36    135.0        ACEVEDO GAGO LIZ PATRICH ANKY
# 17         58006F   506.84    291.0           ACHA CONDORI ERIKA VALERIA
# 18         20751E   426.32    450.0       ACHALMA GALINDO MARIO FERNANDO
# 19         20642C   359.20    297.0              ACHAYA SURCO HENRY LUIS
# 20         62901J   453.72    276.0       ACHONG BONILLA JORGE GUILLERMO
# 21         30085F   285.32     60.0              ACORI VALLES JORGE LUIS
# 22         62833G   481.48    180.0  ACOSTA CASIQUE LUIS FERNANDO JUNIOR
# 23         30263E   526.40    384.0      ACOSTA CHAPOÑAN MARIA BENEDICTA
# 24        31787FI   488.48    276.0            ACOSTA CORREA ANGEL BRYAN
# 25         60391B   282.92    312.0          ACOSTA GIRALDEZ ARON JUNIOR
# 26         10089B   479.64    165.0    ACOSTA JULCA DONNA MARIA MERCEDES
# 27         20388G   423.44    324.0         ACOSTA MEZA CRISTHIAN FAUSTO
# 28         30258D   389.40    357.0           ACOSTA SULCA ALEX CRISTIAN
# 29         32391C   410.76    141.0         ACOSTA TINGAL JOHAN LEONARDO
# ...           ...      ...      ...                                  ...
# 6148   614962925E   168.40     27.0           ZELA HUAMÁN VICTOR RONALDO
# 6149   615020840J   537.92    375.0         ZELADA RODRÍGUEZ JHON ANTONY
# 6150  615141192AI   375.04    348.0       ZELAYA BRICEÑO PERCY ALEXANDER
# 6151   615240034D   532.04    405.0            ZELAYA MEZA DANA SCARLETH
# 6152   615352094K   421.52    258.0           ZENTENO VELA ANDRÉ GERARDO
# 6153   615462636E   505.12    507.0    ZERRILLO GONZALES VICTOR DE JESUS
# 6154     6155046H   438.48    402.0     ZETA MENDEZ REYCAR ANTHONY ELIAS
# 6155   615631713B   371.32    153.0      ZEVALLOS AGUILAR CARLOS RICARDO
# 6156   615731578A   412.08    357.0         ZEVALLOS BELTRAN EDDY ADRIAN
# 6157   615810515B   466.80    444.0         ZEVALLOS MARTEL ANDY MARCELO
# 6158   615952096J   408.04    195.0                ZEVALLOS MASCO ELIANE
# 6159   616041716G   482.16    372.0        ZEVALLOS VARGAS LUIS FERNANDO
# 6160    66162313F   476.28    360.0         ZULUETA ALVARADO DIEGO EDSON
# 6161    61631356J   494.00    228.0         ZULUETA FLORES XIOMARA HELEN
# 6162    61632356A   423.72    234.0            ZULUETA PARDO RENZO FIDEL
# 6163    61631786A   475.96    246.0             ZUMAETA DAVILA GIANMARCO
# 6164    61641874B   326.76    177.0      ZUMAETA SUBIZARRETA GARY MARVIN
# 6165    16630126A   532.44    213.0          ZUMAETA VIGIL JORGE ANTONIO
# 6166    61630015K   536.08    477.0          ZUMBA HUACCHA MIGUEL ALONZO
# 6167   61610180DI   537.76    192.0          ZUÑIGA CALDERON WALTER HUGO
# 6168   61660384BI   584.24    360.0         ZUÑIGA CCORA FERNANDO CARLOS
# 6169   617051816K   477.12    219.0    ZUÑIGA DURAN KIMBERLEY TEODOLINDA
# 6170   617132082F   387.36     87.0           ZUÑIGA ESCOBEDO ANGIE ROSE
# 6171   617252031E   386.48    117.0             ZUÑIGA NUÑEZ KAROL SOFIA
# 6172   617320837H   398.96     75.0       ZUÑIGA ROJAS DIEGO MAXIMILIANO
# 6173   617462627F   479.68    285.0           ZUÑIGA RUIZ CRISTIAN DAVID
# 6174   617590031A   220.48      1.0       ZUÑIGA URBAY RICARDO JIMI JOHN
# 6175   617630007F   312.64    108.0           AZURITA PALOMINO JEAN PAUL
# 6176     6741299F   431.12    342.0           ZUTA TUESTA BEIMER ROLANDO
# 6177   617810506C   298.88     90.0              ZUTA VASQUEZ JOSE DUGAR
#
#         total
# 0      521.08
# 1      211.52
# 2      799.72
# 3      357.48
# 4      522.12
# 5      292.08
# 6      660.40
# 7      396.60
# 8      817.84
# 9      780.68
# 10     905.52
# 11     444.24
# 12     771.12
# 13     845.60
# 14     742.96
# 15     429.52
# 16     530.36
# 17     797.84
# 18     876.32
# 19     656.20
# 20     729.72
# 21     345.32
# 22     661.48
# 23     910.40
# 24     764.48
# 25     594.92
# 26     644.64
# 27     747.44
# 28     746.40
# 29     551.76
# ...       ...
# 6148   195.40
# 6149   912.92
# 6150   723.04
# 6151   937.04
# 6152   679.52
# 6153  1012.12
# 6154   840.48
# 6155   524.32
# 6156   769.08
# 6157   910.80
# 6158   603.04
# 6159   854.16
# 6160   836.28
# 6161   722.00
# 6162   657.72
# 6163   721.96
# 6164   503.76
# 6165   745.44
# 6166  1013.08
# 6167   729.76
# 6168   944.24
# 6169   696.12
# 6170   474.36
# 6171   503.48
# 6172   473.96
# 6173   764.68
# 6174   221.48
# 6175   420.64
# 6176   773.12
# 6177   388.88
#
# [6178 rows x 5 columns]

# %%
data_final.describe()
# Out:
#            examen1      examen2        total
# count  6178.000000  6178.000000  6178.000000
# mean    393.620434   247.399158   641.019592
# std      96.861118   131.487138   208.372757
# min       0.000000     0.000000     0.000000
# 25%     338.320000   147.000000   496.700000
# 50%     402.440000   246.000000   652.220000
# 75%     460.120000   348.000000   794.390000
# max     662.200000   600.000000  1237.640000

# %%
# the histogram of the data
plt.hist(data_final['sumNotas'])

plt.show()

# %%
data_final[data_final.sumNotas > 1000].count()
# Out:
# name        192
# nota1       192
# nota2       192
# sumNotas    192
# dtype: int64

# %%
data_final.ix[data_final['nota1'].idxmax()]
# Out:
# DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated [ipykernel_launcher.py:1]
# name        FLORES PONTE LUIS FERNANDO
# nota1                            662.2
# nota2                              549
# sumNotas                        1211.2
# Name: 2047, dtype: object

# %%
data_final.ix[data_final['nota2'].idxmax()]
# Out:
# name        DIONISIO PINEDO ROSA CRISTINA
# nota1                              260.56
# nota2                                 600
# sumNotas                           860.56
# Name: 1743, dtype: object

# %%
data_final.ix[data_final['sumNotas'].idxmax()]
# Out:
# name        FABIÁN SALINAS ANDRÉS BENJAMÍN
# nota1                               637.64
# nota2                                  600
# sumNotas                           1237.64
# Name: 1906, dtype: object

# %%
page = 0
pagina = fileReader.getPage(page)
texto_pagina=pagina.extractText()

# Obteniendo el cuerpo
# separando la cabecera
body = texto_pagina.split("viernes 16 de  febrero 2018",1)
body = body[1]
body = body.split("OCAD-UNI")
final_body = body[0]
#final_body

# %%
d = r'([A-Z][0-9]|[A-Z])-([0-9][0-9][0-9]|[A-Z]|[0-9][0-9][A-Z])'
l = re.compile(d).split(final_body)
#l
arrayAlumnos = []
count = 1
for i in range(0,len(l),3):
    raw_alumno = l[i]
    #print(raw_alumno)
    f = r'([0-9])|AUSENTE'
    test = re.compile(f).split(raw_alumno,1)
    name = test[0]
    resto = test[1:]
    resto = ['AUSENTE' if v is None else v for v in resto]
    raw_notas  = ''.join(resto)
    gg = r',([0-9]{3})|AUSENTE'
    test2 = re.compile(gg).split(raw_notas)
    test2 = ['0' if v is None else v for v in test2]
    test2 = ['0' if v is '' else v for v in test2]
    notas = []
    for i in range(0,len(test2)-1,2):
            #print(test2)
            dec = test2[i]
            cent = test2[i+1]
            tota_num = dec + '.' + cent
            final_num = float(tota_num)
            notas.append(final_num)
    # cadena de codigo [numero][codigo] (juntos)
    codigo = test2[len(test2)-1]
    firstNUM = str(count)
    codigo = codigo.replace(firstNUM, "", 1)
    #print(codigo.find(firstNUM))
    print(codigo)
    print(notas)
    count=count+1
    #notas = []
    #notas
# Out:
#  51897D
# [446.08, 75.0, 521.08]
#  30346D*
# [210.52, 1.0, 211.52]
#  41901F
# [559.72, 240.0, 799.72]
#  41032G
# [183.48, 174.0, 357.48]
#  62514F
# [342.12, 180.0, 522.12]
#  42154H
# [265.08, 27.0, 292.08]
#  41919F
# [297.4, 363.0, 660.4]
#  50048G
# [312.6, 84.0, 396.6]
#  40263F
# [505.84, 312.0, 817.84]
#  81001K
# [429.68, 351.0, 780.68]
#  41613K
# [506.52, 399.0, 905.52]
#  42077F
# [432.24, 12.0, 444.24]
#  40022A
# [522.12, 249.0, 771.12]
#  10484K
# [578.6, 267.0, 845.6]
#  81002K
# [460.96, 282.0, 742.96]
#  41291J
# [411.52, 18.0, 429.52]
#  32348G
# [395.36, 135.0, 530.36]
#  58006F
# [506.84, 291.0, 797.84]
#  20751E
# [426.32, 450.0, 876.32]
#  20642C
# [359.2, 297.0, 656.2]
#  62901J
# [453.72, 276.0, 729.72]
#  30085F
# [285.32, 60.0, 345.32]
#  62833G
# [481.48, 180.0, 661.48]
#  30263E
# [526.4, 384.0, 910.4]
#  31787FI
# [488.48, 276.0, 764.48]
#  60391B
# [282.92, 312.0, 594.92]
#  10089B
# [479.64, 165.0, 644.64]
#  20388G
# [423.44, 324.0, 747.44]
#  30258D
# [389.4, 357.0, 746.4]
#  32391C
# [410.76, 141.0, 551.76]
#  30398AI
# [462.52, 345.0, 807.52]
#  20436B
# [289.6, 357.0, 646.6]
#  40179D
# [387.72, 390.0, 777.72]
#  62351A
# [466.12, 318.0, 784.12]
#  62992G
# [437.28, 144.0, 581.28]
#  31638J
# [366.64, 366.0, 732.64]
#  41795A
# [275.52, 150.0, 425.52]
#  40896GI
# [339.96, 390.0, 729.96]
#  62886I
# [400.36, 303.0, 703.36]
#  60251E
# [452.12, 369.0, 821.12]
#  20573F
# [454.64, 180.0, 634.64]
#  30215F
# [234.08, 78.0, 312.08]
#  62572I
# [360.24, 204.0, 564.24]
#  31972E
# [472.56, 366.0, 838.56]
#  30251B
# [378.76, 201.0, 579.76]
#  62771J
# [435.76, 129.0, 564.76]
#  20011AI
# [236.72, 6.0, 242.72]
#  32313C
# [322.44, 45.0, 367.44]
#  20061J
# [516.52, 312.0, 828.52]
#  20491A
# [421.92, 504.0, 925.92]
#  62690J
# [334.72, 246.0, 580.72]
#  20230J
# [345.52, 258.0, 603.52]
#  41785H
# [249.08, 45.0, 294.08]
#  62472F
# [254.44, 108.0, 362.44]
#  20520D
# [485.4, 426.0, 911.4]
# 0
# []
